# %%
# %matplotlib ipympl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from sklearn.cluster import KMeans
import tabulate
import sys
import pickle
import os
from scipy import stats
from autorank import autorank,create_report,plot_stats
from significance_analysis import conduct_analysis
pd.set_option("chained_assignment", None)
pd.set_option("display.max_rows", 5000)
pd.set_option("display.max_columns", 5000)
pd.set_option("display.width", 10000)

def load_priorband_data(combine_bench_prior:bool=True):
    df = pd.read_parquet("data_for_anton.parquet")
    df=df.reset_index()
    df_collection=[]
    for seed_nr in range(50):
        partial_df=df[["benchmark","prior","algorithm","used_fidelity"]]
        partial_df["value"]=df[f"seed-{seed_nr}"]
        partial_df["seed"]=seed_nr
        df_collection.append(partial_df)
        print(f"⚙️ Seed {seed_nr+1}/50", end="\r", flush=True)
    complete_df=pd.concat(df_collection,ignore_index=True)
    
    if combine_bench_prior:
        def combine_bench_priors(row):
            return f"{row['benchmark']}_{row['prior']}"
        complete_df["bench_prior"]=complete_df.apply(combine_bench_priors,axis=1)
    print("✅ Loading data done")
    return complete_df

def add_regret(df:pd.DataFrame,normalize:False):
    best={}
    ranges={}
    print("⚙️ Preparing regret", end="\r", flush=True)
    for benchmark in df["benchmark"].unique():
        best[benchmark]=min(df.loc[df["benchmark"]==benchmark]["value"])
        ranges[benchmark]=max(df.loc[df["benchmark"]==benchmark]["value"])-best[benchmark]
        
    def calculate_simple_regret(row,normalize:bool=False):
        if normalize:
            return abs(best[row["benchmark"]]-row["value"])/ranges[row["benchmark"]]
        return abs(best[row["benchmark"]]-row["value"])
    
    if normalize:
        print("⚙️ Adding regret       ", end="\r", flush=True)
        df['regret'] = df.apply(calculate_simple_regret, axis=1,normalize=True)
        print("✅ Adding regret done                      ")
    else:
        print("⚙️ Adding normalized regret       ", end="\r", flush=True)
        df['norm_regret'] = df.apply(calculate_simple_regret, axis=1,normalize=False)
        print("✅ Adding normalized regret done                      ")
    return df

def create_df_dict(df:pd.DataFrame,experiment:dict):
    df_dict={}
    for p_n,prior_key in enumerate(experiment["priors"]):
        df_dict[prior_key]={}
        for b_n,benchmark in enumerate(experiment["benchmarks"]):
            print(f"⚙️ Prior {prior_key} ({p_n+1}), Benchmark {b_n+1}/{len(experiment['benchmarks'])}      ", end="\r", flush=True)
            df_dict[prior_key][benchmark]={}
            for algo_key,algo_value in experiment["algo_dict"].items():
                df_dict[prior_key][benchmark][algo_key]=df.loc[(df["prior"].isin(experiment["prior_dict"][prior_key]))&(df["algorithm"].isin(algo_value))&(df["bench_prior"]==benchmark)].reset_index(drop=True)
    print("✅ Creating df-dict done                     ")
    return df_dict

def create_lmem_incumbent(df_dict:pd.DataFrame,experiment:dict,cumulative:bool=False,value:list[str]=["value"]):
    fs=experiment["f_space"]
    algorithms=experiment["algorithms"]
    algo_group=experiment["algo_group"]
    benchmarks=experiment["benchmarks"]
    priors=experiment["priors"]
    
    output={}
    output["dataset"]={}
    for p_n,prior in enumerate(priors):
        output["dataset"][prior]={}
        for n_f,max_f in enumerate(fs):
            output["dataset"][prior][max_f]={}
            output["dataset"][prior][max_f]=pd.DataFrame()
            for b_n,benchmark in enumerate(benchmarks):
                df_at_point=df_dict[prior][benchmark][algo_group]
                df_at_point=df_at_point.loc[df_at_point["used_fidelity"]<=max_f]
                for seed in df_at_point["seed"].unique():
                    print(f"⚙️ Prior {prior} ({p_n+1}), Fidelity {n_f+1}/{len(fs)}, Benchmark {b_n+1}/{len(benchmarks)}          ", end="\r", flush=True)
                    for algo in algorithms:
                        df_criteria=df_at_point.loc[(df_at_point["seed"]==seed)&(df_at_point["algorithm"]==algo)].iloc[-1].to_frame().T
                        df_criteria["used_fidelity"]=max_f
                        output["dataset"][prior][max_f]=pd.concat([output["dataset"][prior][max_f],df_criteria],ignore_index=True)
            output["dataset"][prior][max_f][value+["used_fidelity"]]=output["dataset"][prior][max_f][value+["used_fidelity"]].astype(float)
            output["dataset"][prior][max_f]["seed"]=output["dataset"][prior][max_f]["seed"].astype(int)
    print("✅ Creating incumbent data done                                              ")
    if not cumulative:
        return output["dataset"]
    cumulative_data={}
    for p_n,prior in enumerate(priors):
        cumulative_data[prior]={}
        for max_f in experiment["budgets"]:
            cumulative_data[prior][max_f]=pd.DataFrame()
            for fidelity in [item for item in experiment["f_space"] if experiment["min_f"] <= item <= max_f]:
                cumulative_data[prior][max_f]=pd.concat([cumulative_data[prior][max_f],output["dataset"][prior][fidelity]],ignore_index=True)

    return cumulative_data

def run_lmems(experiment:dict,values:list[str]=["value"]):
    result_dict={}
    for v_n,value in enumerate(values):
        result_dict[value]={}
        for p_n,priortype in enumerate(experiment["priors"]):
            result_dict[value][priortype]={}
            for f_n,max_f in enumerate(experiment["budgets"]):
                print(f"⚙️ Value {value}({v_n+1}), Prior {priortype}({p_n+1}), Fidelity {f_n+1}/{len(experiment['budgets'])}        ", end="\r", flush=True)
                experiment["dataset"][priortype][max_f]=experiment["dataset"][priortype][max_f].replace({"algorithm": experiment["label_dict"],"benchmark": experiment["label_dict"]})
                real_stdout = sys.stdout
                sys.stdout = open(os.devnull, "w")
                if len(experiment["dataset"][priortype][max_f]["used_fidelity"].unique())>1:
                    print(experiment["dataset"][priortype][max_f]["used_fidelity"].unique())
                    result_dict[value][priortype][max_f]=conduct_analysis(experiment["dataset"][priortype][max_f],value,"algorithm","benchmark",bin_id="used_fidelity",continuous_fidelity=False,show_plots=False,verbosity=0)[1]
                else:
                    result_dict[value][priortype][max_f]=conduct_analysis(experiment["dataset"][priortype][max_f],value,"algorithm","benchmark",continuous_fidelity=False,show_plots=False,verbosity=0)[1]
                sys.stdout = real_stdout
    print("✅ Running experiments done                                                             ")
    return result_dict

def plot_cd_diagrams(experiment:dict,value:str="value"):
    color_dict={"random_search":"red","hyperband":"green","pb_mutation_dynamic_geometric-default-at-target":"blue","priorband":"blue","RS":"red","HB":"green","PB":"blue"}

    _ = plt.figure(figsize=(10,10*len(experiment["budgets"])/3))
    gs=GridSpec(nrows=len(experiment["budgets"]),ncols=len(experiment["priors"]))
    for p_n,prior in enumerate(experiment["priors"]):
        for f_n,fidelity in enumerate(experiment["budgets"]):
            if fidelity>experiment["min_f"] and experiment["granularity"]:
                scoreframe=experiment["result_dict"][value][prior][fidelity][0].loc[experiment["result_dict"][value][prior][fidelity][0]["used_fidelity_bins"]==str(float(fidelity))].sort_values(by=['Estimate'])[["algorithm","Estimate"]]
                contrastframe=experiment["result_dict"][value][prior][fidelity][1].loc[experiment["result_dict"][value][prior][fidelity][1]["used_fidelity_bins"]==str(float(fidelity))][["Sig","algorithm_1","algorithm_2"]]
            else:
                scoreframe=experiment["result_dict"][value][prior][fidelity][0].sort_values(by=['Estimate'])[["algorithm","Estimate"]]
                contrastframe=experiment["result_dict"][value][prior][fidelity][1][["Sig","algorithm_1","algorithm_2"]]

            min_score=scoreframe["Estimate"][0]
            max_score=scoreframe["Estimate"][len(scoreframe["Estimate"])-1]

            significance_lines=[]
            for n_best_algo,best_algo in enumerate(scoreframe["algorithm"]):
                for n_worst_algo,worst_algo in reversed(list(enumerate(scoreframe["algorithm"][n_best_algo+1:]))):
                    significance=contrastframe.loc[((contrastframe["algorithm_1"]==best_algo)&(contrastframe["algorithm_2"]==worst_algo))|((contrastframe["algorithm_2"]==best_algo)&(contrastframe["algorithm_1"]==worst_algo))]["Sig"][0]
                    if significance in ["","."]:
                        new_line=[n_best_algo,n_best_algo+n_worst_algo+1]
                        if not any(existing_pair[0] <= new_line[0] <= existing_pair[1] and existing_pair[0] <= new_line[1] <= existing_pair[1] for existing_pair in significance_lines):
                            significance_lines.append([n_best_algo,n_best_algo+n_worst_algo+1])
                            break
            n_sign_lines=len(significance_lines)
            plot_height=10+5

            ax=plt.subplot(gs[f_n,p_n])
            
            ax.set_title(f"{fidelity}x {prior}",pad=0,y=-0.18)
            ax.get_yaxis().set_visible(False)
            ax.set_xlim(min_score-(max_score-min_score)*0.1,max_score+(max_score-min_score)*0.1)
            ax.set_ylim(0,plot_height)
            ax.spines['bottom'].set_position(('data', 0.0))
            ax.spines[['top',"left","right"]].set_visible(False)
            ax.invert_xaxis()

            for algo in range(len(scoreframe["Estimate"])):
                ax.plot([scoreframe["Estimate"][algo],scoreframe["Estimate"][algo]], [0, plot_height-6], '-', lw=2, label="_not in legend",color=color_dict[scoreframe["algorithm"][algo]])
                ax.text(scoreframe["Estimate"][algo], plot_height-3, scoreframe["algorithm"][algo], horizontalalignment='center',verticalalignment='bottom')
                ax.text(scoreframe["Estimate"][algo], plot_height-5, np.round(scoreframe["Estimate"][algo],2), horizontalalignment='center',verticalalignment='bottom')
            for n_line,line in enumerate(significance_lines):
                if scoreframe["Estimate"][line[0]]==scoreframe["Estimate"][line[1]]:
                    ax.plot([scoreframe["Estimate"][line[0]], scoreframe["Estimate"][line[1]]],[10/(n_sign_lines+1)*(n_line+1)-0.5,10/(n_sign_lines+1)*(n_line+1)+0.5],  '-', lw=2, label="_not in legend",color="gray")
                else:
                    ax.plot([scoreframe["Estimate"][line[0]], scoreframe["Estimate"][line[1]]],[10/(n_sign_lines+1)*(n_line+1),10/(n_sign_lines+1)*(n_line+1)],  '-', lw=6, label="_not in legend",color="gray")
    print(f"Granularity: {experiment['granularity']}, Value: {value}")
    plt.show()

# %%
def run_experiment(priors:list[str]=["good+bad"],budgets:list[float]=[1.0,5.0,12.0],granularity:int=0,value:list[str]=["value"],min_f:float=1.0,plot:bool=True,benchmarks:list[str]=["jahs_cifar10","jahs_colorectal_histology","jahs_fashion_mnist","lcbench-126026","lcbench-167190","lcbench-168330","lcbench-168910","lcbench-189906","cifar100_wideresnet_2048","imagenet_resnet_512","lm1b_transformer_2048","translatewmt_xformer_64"]):
    experiment={}
    experiment["algo_dict"]={"rs_hb_pb":["random_search","hyperband","pb_mutation_dynamic_geometric-default-at-target"]}
    experiment["prior_dict"]={"good+bad":["at25","bad"],"good":["at25"],"bad":["bad"]}
    experiment["benchmarks"]=benchmarks
    experiment["label_dict"]={'random_search': 'RS', 'hyperband': 'HB', 'pb_mutation_dynamic_geometric-default-at-target': 'PB', 'jahs_cifar10': 'JAHS-C10', 'jahs_colorectal_histology': 'JAHS-CH', 'jahs_fashion_mnist': 'JAHS-FM', 'lcbench-126026': 'LC-126026', 'lcbench-167190': 'LC-167190', 'lcbench-168330': 'LC-168330', 'lcbench-168910': 'LC-168910', 'lcbench-189906': 'LC-189906', 'cifar100_wideresnet_2048': 'PD1-Cifar100', 'imagenet_resnet_512': 'PD1-ImageNet', 'lm1b_transformer_2048': 'PD1-LM1B', 'translatewmt_xformer_64': 'PD1-WMT',"random_search_prior":"RS+Prior","bo":"BO","pibo":"PiBO","bohb":"BOHB","priorband_bo":"PriorBand+BO"}
    experiment["algo_group"]="rs_hb_pb"
    experiment["algorithms"]=experiment["algo_dict"][experiment["algo_group"]]
    experiment["priors"]=priors
    experiment["budgets"]=budgets
    experiment["min_f"]=min_f
    experiment["granularity"]=granularity
    if experiment["granularity"]:
        experiment["f_space"]=np.round(np.linspace(experiment["min_f"],max(experiment["budgets"]),(experiment["granularity"]*round(max(experiment["budgets"])-experiment["min_f"]))+1),3).tolist()
    else:
        experiment["f_space"]=experiment["budgets"]

    df=load_priorband_data()
    if "regret" in value:
        df=add_regret(df,False)
    if "norm_regret" in value:
        df=add_regret(df,True)
    df_dict=create_df_dict(df,experiment)
    experiment["dataset"]=create_lmem_incumbent(df_dict,experiment,cumulative=experiment["granularity"],value=value)
    experiment["result_dict"]=run_lmems(experiment,value)
    if plot:
        for v in value:
            plot_cd_diagrams(experiment,v)
    return experiment

# %%
if False:

    exp_benchmarks_results={}
    benchmark_list=["jahs_cifar10","jahs_colorectal_histology","jahs_fashion_mnist","lcbench-126026","lcbench-167190","lcbench-168330","lcbench-168910","lcbench-189906","cifar100_wideresnet_2048","imagenet_resnet_512","lm1b_transformer_2048","translatewmt_xformer_64"]
    bench_prior_list=[]
    for benchmark in benchmark_list:
        bench_prior_list.append(benchmark+"_at25")
        bench_prior_list.append(benchmark+"_bad")
    for b_n,benchmark in enumerate(bench_prior_list):
        print(f"❗{b_n+1}. Running Benchmark {benchmark}")
        exp_benchmarks_results[benchmark]=run_experiment(["good+bad"],[1,5,12],0,["value","regret","norm_regret"],plot=False,benchmarks=[benchmark])["result_dict"]


    with open("experiment.pickle","wb") as f:
        pickle.dump(exp_benchmarks_results,f)


with open("experiment.pickle","rb") as f:
    exp_benchmarks_results=pickle.load(f)

# %%
dataset=pd.DataFrame(columns=["value_type","benchmark_prior","prior","fidelity","RS - HB","RS - PB","HB - PB"])
for benchmark in exp_benchmarks_results.keys():
    for value in exp_benchmarks_results[benchmark].keys():
        for fidelity in exp_benchmarks_results[benchmark][value]["good+bad"].keys():
            contrastframe=exp_benchmarks_results[benchmark][value]["good+bad"][fidelity][1]
            new_row=[value,benchmark,"good+bad",fidelity,(1-contrastframe["P-val"][0])*np.sign(contrastframe["Estimate"][0]),(1-contrastframe["P-val"][1])*np.sign(contrastframe["Estimate"][1]),(1-contrastframe["P-val"][2])*np.sign(contrastframe["Estimate"][2])]
            new_row=[new_row]
            dataset=pd.concat([dataset,pd.DataFrame(new_row,columns=dataset.columns)],ignore_index=True)
print(dataset)
# Out:
#       value_type                 benchmark_prior     prior fidelity  RS - HB  RS - PB  HB - PB
# 0          value               jahs_cifar10_at25  good+bad        1   -1.000    1.000    1.000
# 1          value               jahs_cifar10_at25  good+bad        5    0.555    1.000    1.000
# 2          value               jahs_cifar10_at25  good+bad       12    0.953    1.000    1.000
# 3         regret               jahs_cifar10_at25  good+bad        1   -1.000    1.000    1.000
# 4         regret               jahs_cifar10_at25  good+bad        5    0.555    1.000    1.000
# 5         regret               jahs_cifar10_at25  good+bad       12    0.953    1.000    1.000
# 6    norm_regret               jahs_cifar10_at25  good+bad        1   -1.000    1.000    1.000
# 7    norm_regret               jahs_cifar10_at25  good+bad        5    0.555    1.000    1.000
# 8    norm_regret               jahs_cifar10_at25  good+bad       12    0.953    1.000    1.000
# 9          value                jahs_cifar10_bad  good+bad        1   -1.000   -1.000   -1.000
# 10         value                jahs_cifar10_bad  good+bad        5    0.404   -0.310   -0.825
# 11         value                jahs_cifar10_bad  good+bad       12    0.917    0.920    0.000
# 12        regret                jahs_cifar10_bad  good+bad        1   -1.000   -1.000   -1.000
# 13        regret                jahs_cifar10_bad  good+bad        5    0.404   -0.310   -0.825
# 14        regret                jahs_cifar10_bad  good+bad       12    0.917    0.920    0.000
# 15   norm_regret                jahs_cifar10_bad  good+bad        1   -1.000   -1.000   -1.000
# 16   norm_regret                jahs_cifar10_bad  good+bad        5    0.404   -0.310   -0.825
# 17   norm_regret                jahs_cifar10_bad  good+bad       12    0.917    0.920    0.000
# 18         value  jahs_colorectal_histology_at25  good+bad        1   -1.000    1.000    1.000
# 19         value  jahs_colorectal_histology_at25  good+bad        5    0.949    1.000    0.886
# 20         value  jahs_colorectal_histology_at25  good+bad       12    0.949    0.997    0.418
# 21        regret  jahs_colorectal_histology_at25  good+bad        1   -1.000    1.000    1.000
# 22        regret  jahs_colorectal_histology_at25  good+bad        5    0.949    1.000    0.886
# 23        regret  jahs_colorectal_histology_at25  good+bad       12    0.949    0.997    0.418
# 24   norm_regret  jahs_colorectal_histology_at25  good+bad        1   -1.000    1.000    1.000
# 25   norm_regret  jahs_colorectal_histology_at25  good+bad        5    0.949    1.000    0.886
# 26   norm_regret  jahs_colorectal_histology_at25  good+bad       12    0.949    0.997    0.418
# 27         value   jahs_colorectal_histology_bad  good+bad        1   -1.000   -1.000   -1.000
# 28         value   jahs_colorectal_histology_bad  good+bad        5    0.855    0.357   -0.418
# 29         value   jahs_colorectal_histology_bad  good+bad       12    0.935    0.998    0.581
# 30        regret   jahs_colorectal_histology_bad  good+bad        1   -1.000   -1.000   -1.000
# 31        regret   jahs_colorectal_histology_bad  good+bad        5    0.855    0.357   -0.418
# 32        regret   jahs_colorectal_histology_bad  good+bad       12    0.935    0.998    0.581
# 33   norm_regret   jahs_colorectal_histology_bad  good+bad        1   -1.000   -1.000   -1.000
# 34   norm_regret   jahs_colorectal_histology_bad  good+bad        5    0.855    0.357   -0.418
# 35   norm_regret   jahs_colorectal_histology_bad  good+bad       12    0.935    0.998    0.581
# 36         value         jahs_fashion_mnist_at25  good+bad        1   -1.000    1.000    1.000
# 37         value         jahs_fashion_mnist_at25  good+bad        5   -0.999    1.000    1.000
# 38         value         jahs_fashion_mnist_at25  good+bad       12   -0.076    1.000    1.000
# 39        regret         jahs_fashion_mnist_at25  good+bad        1   -1.000    1.000    1.000
# 40        regret         jahs_fashion_mnist_at25  good+bad        5   -0.999    1.000    1.000
# 41        regret         jahs_fashion_mnist_at25  good+bad       12    0.000    1.000    1.000
# 42   norm_regret         jahs_fashion_mnist_at25  good+bad        1   -1.000    1.000    1.000
# 43   norm_regret         jahs_fashion_mnist_at25  good+bad        5   -0.999    1.000    1.000
# 44   norm_regret         jahs_fashion_mnist_at25  good+bad       12   -0.076    1.000    1.000
# 45         value          jahs_fashion_mnist_bad  good+bad        1   -1.000   -1.000   -1.000
# 46         value          jahs_fashion_mnist_bad  good+bad        5   -0.987   -0.997   -0.119
# 47         value          jahs_fashion_mnist_bad  good+bad       12   -0.056    0.005    0.091
# 48        regret          jahs_fashion_mnist_bad  good+bad        1   -1.000   -1.000   -1.000
# 49        regret          jahs_fashion_mnist_bad  good+bad        5   -0.987   -0.997   -0.119
# 50        regret          jahs_fashion_mnist_bad  good+bad       12    0.000    0.000    0.000
# 51   norm_regret          jahs_fashion_mnist_bad  good+bad        1   -1.000   -1.000   -1.000
# 52   norm_regret          jahs_fashion_mnist_bad  good+bad        5   -0.987   -0.997   -0.119
# 53   norm_regret          jahs_fashion_mnist_bad  good+bad       12   -0.056    0.005    0.091
# 54         value             lcbench-126026_at25  good+bad        1    0.992    1.000    0.935
# 55         value             lcbench-126026_at25  good+bad        5    1.000    1.000    0.249
# 56         value             lcbench-126026_at25  good+bad       12    1.000    1.000    0.733
# 57        regret             lcbench-126026_at25  good+bad        1    0.992    1.000    0.935
# 58        regret             lcbench-126026_at25  good+bad        5    1.000    1.000    0.249
# 59        regret             lcbench-126026_at25  good+bad       12    1.000    1.000    0.733
# 60   norm_regret             lcbench-126026_at25  good+bad        1    0.992    1.000    0.935
# 61   norm_regret             lcbench-126026_at25  good+bad        5    1.000    1.000    0.249
# 62   norm_regret             lcbench-126026_at25  good+bad       12    1.000    1.000    0.733
# 63         value              lcbench-126026_bad  good+bad        1    0.992   -1.000   -1.000
# 64         value              lcbench-126026_bad  good+bad        5    1.000    0.983   -0.989
# 65         value              lcbench-126026_bad  good+bad       12    0.999    0.983   -0.323
# 66        regret              lcbench-126026_bad  good+bad        1    0.992   -1.000   -1.000
# 67        regret              lcbench-126026_bad  good+bad        5    1.000    0.983   -0.989
# 68        regret              lcbench-126026_bad  good+bad       12    0.999    0.983   -0.323
# 69   norm_regret              lcbench-126026_bad  good+bad        1    0.992   -1.000   -1.000
# 70   norm_regret              lcbench-126026_bad  good+bad        5    1.000    0.983   -0.989
# 71   norm_regret              lcbench-126026_bad  good+bad       12    0.999    0.983   -0.323
# 72         value             lcbench-167190_at25  good+bad        1    1.000    1.000    0.233
# 73         value             lcbench-167190_at25  good+bad        5    1.000    1.000   -0.843
# 74         value             lcbench-167190_at25  good+bad       12    1.000    1.000    0.000
# 75        regret             lcbench-167190_at25  good+bad        1    1.000    1.000    0.233
# 76        regret             lcbench-167190_at25  good+bad        5    1.000    1.000   -0.843
# 77        regret             lcbench-167190_at25  good+bad       12    1.000    1.000    0.000
# 78   norm_regret             lcbench-167190_at25  good+bad        1    1.000    1.000    0.233
# 79   norm_regret             lcbench-167190_at25  good+bad        5    1.000    1.000   -0.843
# 80   norm_regret             lcbench-167190_at25  good+bad       12    1.000    1.000    0.000
# 81         value              lcbench-167190_bad  good+bad        1    1.000   -1.000   -1.000
# 82         value              lcbench-167190_bad  good+bad        5    1.000    1.000   -0.356
# 83         value              lcbench-167190_bad  good+bad       12    1.000    1.000    0.392
# 84        regret              lcbench-167190_bad  good+bad        1    1.000   -1.000   -1.000
# 85        regret              lcbench-167190_bad  good+bad        5    1.000    1.000   -0.356
# 86        regret              lcbench-167190_bad  good+bad       12    1.000    1.000    0.392
# 87   norm_regret              lcbench-167190_bad  good+bad        1    1.000   -1.000   -1.000
# 88   norm_regret              lcbench-167190_bad  good+bad        5    1.000    1.000   -0.356
# 89   norm_regret              lcbench-167190_bad  good+bad       12    1.000    1.000    0.392
# 90         value             lcbench-168330_at25  good+bad        1    1.000    1.000    0.013
# 91         value             lcbench-168330_at25  good+bad        5    1.000    1.000   -0.429
# 92         value             lcbench-168330_at25  good+bad       12    0.632    0.986    0.700
# 93        regret             lcbench-168330_at25  good+bad        1    1.000    1.000    0.013
# 94        regret             lcbench-168330_at25  good+bad        5    1.000    1.000   -0.429
# 95        regret             lcbench-168330_at25  good+bad       12    0.632    0.986    0.700
# 96   norm_regret             lcbench-168330_at25  good+bad        1    1.000    1.000    0.013
# 97   norm_regret             lcbench-168330_at25  good+bad        5    1.000    1.000   -0.429
# 98   norm_regret             lcbench-168330_at25  good+bad       12    0.632    0.986    0.700
# 99         value              lcbench-168330_bad  good+bad        1    1.000   -1.000   -1.000
# 100        value              lcbench-168330_bad  good+bad        5    1.000    0.851   -0.994
# 101        value              lcbench-168330_bad  good+bad       12    0.583    0.292   -0.115
# 102       regret              lcbench-168330_bad  good+bad        1    1.000   -1.000   -1.000
# 103       regret              lcbench-168330_bad  good+bad        5    1.000    0.851   -0.994
# 104       regret              lcbench-168330_bad  good+bad       12    0.583    0.292   -0.115
# 105  norm_regret              lcbench-168330_bad  good+bad        1    1.000   -1.000   -1.000
# 106  norm_regret              lcbench-168330_bad  good+bad        5    1.000    0.851   -0.994
# 107  norm_regret              lcbench-168330_bad  good+bad       12    0.583    0.292   -0.115
# 108        value             lcbench-168910_at25  good+bad        1    1.000    1.000    0.859
# 109        value             lcbench-168910_at25  good+bad        5    1.000    1.000    0.009
# 110        value             lcbench-168910_at25  good+bad       12    0.999    1.000    0.988
# 111       regret             lcbench-168910_at25  good+bad        1    1.000    1.000    0.859
# 112       regret             lcbench-168910_at25  good+bad        5    1.000    1.000    0.009
# 113       regret             lcbench-168910_at25  good+bad       12    0.999    1.000    0.988
# 114  norm_regret             lcbench-168910_at25  good+bad        1    1.000    1.000    0.859
# 115  norm_regret             lcbench-168910_at25  good+bad        5    1.000    1.000    0.009
# 116  norm_regret             lcbench-168910_at25  good+bad       12    0.999    1.000    0.988
# 117        value              lcbench-168910_bad  good+bad        1    1.000   -1.000   -1.000
# 118        value              lcbench-168910_bad  good+bad        5    1.000    1.000    0.057
# 119        value              lcbench-168910_bad  good+bad       12    1.000    1.000    0.931
# 120       regret              lcbench-168910_bad  good+bad        1    1.000   -1.000   -1.000
# 121       regret              lcbench-168910_bad  good+bad        5    1.000    1.000    0.057
# 122       regret              lcbench-168910_bad  good+bad       12    1.000    1.000    0.931
# 123  norm_regret              lcbench-168910_bad  good+bad        1    1.000   -1.000   -1.000
# 124  norm_regret              lcbench-168910_bad  good+bad        5    1.000    1.000    0.057
# 125  norm_regret              lcbench-168910_bad  good+bad       12    1.000    1.000    0.931
# 126        value             lcbench-189906_at25  good+bad        1    1.000    1.000    0.987
# 127        value             lcbench-189906_at25  good+bad        5    1.000    1.000   -0.003
# 128        value             lcbench-189906_at25  good+bad       12    1.000    1.000    0.954
# 129       regret             lcbench-189906_at25  good+bad        1    1.000    1.000    0.987
# 130       regret             lcbench-189906_at25  good+bad        5    1.000    1.000   -0.003
# 131       regret             lcbench-189906_at25  good+bad       12    1.000    1.000    0.954
# 132  norm_regret             lcbench-189906_at25  good+bad        1    1.000    1.000    0.987
# 133  norm_regret             lcbench-189906_at25  good+bad        5    1.000    1.000   -0.003
# 134  norm_regret             lcbench-189906_at25  good+bad       12    1.000    1.000    0.954
# 135        value              lcbench-189906_bad  good+bad        1    1.000   -1.000   -1.000
# 136        value              lcbench-189906_bad  good+bad        5    1.000    1.000   -0.938
# 137        value              lcbench-189906_bad  good+bad       12    0.999    0.988   -0.391
# 138       regret              lcbench-189906_bad  good+bad        1    1.000   -1.000   -1.000
# 139       regret              lcbench-189906_bad  good+bad        5    1.000    1.000   -0.938
# 140       regret              lcbench-189906_bad  good+bad       12    0.999    0.988   -0.391
# 141  norm_regret              lcbench-189906_bad  good+bad        1    1.000   -1.000   -1.000
# 142  norm_regret              lcbench-189906_bad  good+bad        5    1.000    1.000   -0.938
# 143  norm_regret              lcbench-189906_bad  good+bad       12    0.999    0.988   -0.391
# 144        value   cifar100_wideresnet_2048_at25  good+bad        1    0.947    1.000    1.000
# 145        value   cifar100_wideresnet_2048_at25  good+bad        5    0.414    1.000    1.000
# 146        value   cifar100_wideresnet_2048_at25  good+bad       12    0.572    1.000    1.000
# 147       regret   cifar100_wideresnet_2048_at25  good+bad        1    0.947    1.000    1.000
# 148       regret   cifar100_wideresnet_2048_at25  good+bad        5    0.414    1.000    1.000
# 149       regret   cifar100_wideresnet_2048_at25  good+bad       12    0.572    1.000    1.000
# 150  norm_regret   cifar100_wideresnet_2048_at25  good+bad        1    0.947    1.000    1.000
# 151  norm_regret   cifar100_wideresnet_2048_at25  good+bad        5    0.414    1.000    1.000
# 152  norm_regret   cifar100_wideresnet_2048_at25  good+bad       12    0.572    1.000    1.000
# 153        value    cifar100_wideresnet_2048_bad  good+bad        1    0.947   -1.000   -1.000
# 154        value    cifar100_wideresnet_2048_bad  good+bad        5    0.222   -0.999   -1.000
# 155        value    cifar100_wideresnet_2048_bad  good+bad       12    0.445    0.084   -0.200
# 156       regret    cifar100_wideresnet_2048_bad  good+bad        1    0.947   -1.000   -1.000
# 157       regret    cifar100_wideresnet_2048_bad  good+bad        5    0.222   -0.999   -1.000
# 158       regret    cifar100_wideresnet_2048_bad  good+bad       12    0.445    0.084   -0.200
# 159  norm_regret    cifar100_wideresnet_2048_bad  good+bad        1    0.947   -1.000   -1.000
# 160  norm_regret    cifar100_wideresnet_2048_bad  good+bad        5    0.222   -0.999   -1.000
# 161  norm_regret    cifar100_wideresnet_2048_bad  good+bad       12    0.445    0.084   -0.200
# 162        value        imagenet_resnet_512_at25  good+bad        1    1.000    1.000    1.000
# 163        value        imagenet_resnet_512_at25  good+bad        5    0.916    1.000    1.000
# 164        value        imagenet_resnet_512_at25  good+bad       12    0.977    1.000    1.000
# 165       regret        imagenet_resnet_512_at25  good+bad        1    1.000    1.000    1.000
# 166       regret        imagenet_resnet_512_at25  good+bad        5    0.916    1.000    1.000
# 167       regret        imagenet_resnet_512_at25  good+bad       12    0.977    1.000    1.000
# 168  norm_regret        imagenet_resnet_512_at25  good+bad        1    1.000    1.000    1.000
# 169  norm_regret        imagenet_resnet_512_at25  good+bad        5    0.916    1.000    1.000
# 170  norm_regret        imagenet_resnet_512_at25  good+bad       12    0.977    1.000    1.000
# 171        value         imagenet_resnet_512_bad  good+bad        1    1.000   -1.000   -1.000
# 172        value         imagenet_resnet_512_bad  good+bad        5    0.941    0.728   -0.268
# 173        value         imagenet_resnet_512_bad  good+bad       12    0.953    0.823   -0.183
# 174       regret         imagenet_resnet_512_bad  good+bad        1    1.000   -1.000   -1.000
# 175       regret         imagenet_resnet_512_bad  good+bad        5    0.941    0.728   -0.268
# 176       regret         imagenet_resnet_512_bad  good+bad       12    0.953    0.823   -0.183
# 177  norm_regret         imagenet_resnet_512_bad  good+bad        1    1.000   -1.000   -1.000
# 178  norm_regret         imagenet_resnet_512_bad  good+bad        5    0.941    0.728   -0.268
# 179  norm_regret         imagenet_resnet_512_bad  good+bad       12    0.953    0.823   -0.183
# 180        value      lm1b_transformer_2048_at25  good+bad        1    1.000    1.000    0.999
# 181        value      lm1b_transformer_2048_at25  good+bad        5    1.000    1.000    0.473
# 182        value      lm1b_transformer_2048_at25  good+bad       12    1.000    1.000    0.984
# 183       regret      lm1b_transformer_2048_at25  good+bad        1    1.000    1.000    0.999
# 184       regret      lm1b_transformer_2048_at25  good+bad        5    1.000    1.000    0.473
# 185       regret      lm1b_transformer_2048_at25  good+bad       12    1.000    1.000    0.984
# 186  norm_regret      lm1b_transformer_2048_at25  good+bad        1    1.000    1.000    0.999
# 187  norm_regret      lm1b_transformer_2048_at25  good+bad        5    1.000    1.000    0.473
# 188  norm_regret      lm1b_transformer_2048_at25  good+bad       12    1.000    1.000    0.984
# 189        value       lm1b_transformer_2048_bad  good+bad        1    1.000   -1.000   -1.000
# 190        value       lm1b_transformer_2048_bad  good+bad        5    1.000    1.000   -0.628
# 191        value       lm1b_transformer_2048_bad  good+bad       12    1.000    0.999   -0.091
# 192       regret       lm1b_transformer_2048_bad  good+bad        1    1.000   -1.000   -1.000
# 193       regret       lm1b_transformer_2048_bad  good+bad        5    1.000    1.000   -0.628
# 194       regret       lm1b_transformer_2048_bad  good+bad       12    1.000    0.999   -0.091
# 195  norm_regret       lm1b_transformer_2048_bad  good+bad        1    1.000   -1.000   -1.000
# 196  norm_regret       lm1b_transformer_2048_bad  good+bad        5    1.000    1.000   -0.628
# 197  norm_regret       lm1b_transformer_2048_bad  good+bad       12    1.000    0.999   -0.091
# 198        value    translatewmt_xformer_64_at25  good+bad        1    1.000    1.000    1.000
# 199        value    translatewmt_xformer_64_at25  good+bad        5    1.000    1.000    0.981
# 200        value    translatewmt_xformer_64_at25  good+bad       12    1.000    1.000    0.997
# 201       regret    translatewmt_xformer_64_at25  good+bad        1    1.000    1.000    1.000
# 202       regret    translatewmt_xformer_64_at25  good+bad        5    1.000    1.000    0.981
# 203       regret    translatewmt_xformer_64_at25  good+bad       12    1.000    1.000    0.997
# 204  norm_regret    translatewmt_xformer_64_at25  good+bad        1    1.000    1.000    1.000
# 205  norm_regret    translatewmt_xformer_64_at25  good+bad        5    1.000    1.000    0.981
# 206  norm_regret    translatewmt_xformer_64_at25  good+bad       12    1.000    1.000    0.997
# 207        value     translatewmt_xformer_64_bad  good+bad        1    1.000   -1.000   -1.000
# 208        value     translatewmt_xformer_64_bad  good+bad        5    1.000    0.925   -0.799
# 209        value     translatewmt_xformer_64_bad  good+bad       12    0.999    0.999    0.008
# 210       regret     translatewmt_xformer_64_bad  good+bad        1    1.000   -1.000   -1.000
# 211       regret     translatewmt_xformer_64_bad  good+bad        5    1.000    0.925   -0.799
# 212       regret     translatewmt_xformer_64_bad  good+bad       12    0.999    0.999    0.008
# 213  norm_regret     translatewmt_xformer_64_bad  good+bad        1    1.000   -1.000   -1.000
# 214  norm_regret     translatewmt_xformer_64_bad  good+bad        5    1.000    0.925   -0.799
# 215  norm_regret     translatewmt_xformer_64_bad  good+bad       12    0.999    0.999    0.008

# %%
def simple_clustering(k,data_frame, type_column, numerical_columns, value,fidelity,plot:bool=False):
    # Combine data from all categories
    combined_data = pd.DataFrame()
    for type_value in data_frame[type_column].unique():
        type_data = data_frame[data_frame[type_column] == type_value]
        combined_data = pd.concat([combined_data,type_data])

    # Perform clustering on the combined data
    kmeans = KMeans(n_clusters=k,n_init="auto")
    kmeans.fit(combined_data[numerical_columns])
    cluster_labels = kmeans.labels_
    

    # Assign cluster labels to the original data frame
    data_frame['cluster'] = cluster_labels
    def add_cluster_centers(row,columns,means):
        return means[row["cluster"]]

    data_frame[numerical_columns] = data_frame.apply(add_cluster_centers, axis=1,columns=numerical_columns,means=kmeans.cluster_centers_).to_list()

    if plot:
        # Visualize clusters using Matplotlib
        fig=plt.figure()
        ax=fig.add_subplot(projection="3d")
        
        ax.scatter(combined_data[numerical_columns[0]], combined_data[numerical_columns[1]],combined_data[numerical_columns[2]], c=cluster_labels)
        
        for _,row in combined_data.iterrows():
            ax.text(row[numerical_columns].values[0],row[numerical_columns].values[1],row[numerical_columns].values[2],row[type_column],fontsize=5)

        
        plt.title(f"{k} Clusters in {value} and fidelity {fidelity}")
        # ax.set_xlim([-1, 1])
        # ax.set_ylim([-1, 1])
        # ax.set_zlim([-1,1])
        ax.set_xlabel(numerical_columns[0])
        ax.set_ylabel(numerical_columns[1])
        ax.set_zlabel(numerical_columns[2])
        plt.show()

    return data_frame

meta_feature_df=pd.read_csv("benchmark_metafeatures.csv")
def add_meta_features(row):
    return meta_feature_df.loc[meta_feature_df["code_name"]==row["benchmark_prior"].rsplit('_', 1)[0]][["# Vars","# cont. Vars","# cond. Vars","# cat. Vars","log int","int"]].values[0]

def split_benchmark_prior(row):
    return row["benchmark_prior"].rsplit('_', 1)

clusters={}
for value in dataset["value_type"].unique():
    clusters[value]={}
    for fidelity in dataset["fidelity"].unique():
        sample_df=dataset.loc[(dataset["value_type"]==value)&(dataset["fidelity"]==fidelity)][["benchmark_prior","RS - HB","HB - PB","RS - PB"]]
        clusters[value][fidelity]=simple_clustering(2,sample_df,"benchmark_prior",["RS - HB","HB - PB","RS - PB"],value,fidelity,plot=False)
        clusters[value][fidelity][['benchmark','prior']]=clusters[value][fidelity].apply(split_benchmark_prior,axis=1).to_list()
        # clusters[value][fidelity][["#Vars","#cont. Vars","#cond. Vars","#cat. Vars","log int","int"]]=clusters[value][fidelity].apply(add_meta_features,axis=1).to_list()
        clusters[value][fidelity]=clusters[value][fidelity].sort_values(by=['cluster'])
        print(f"Dataframe for value-type {value} at {fidelity}x Budget \n",clusters[value][fidelity],"\n")
# Out:
# Dataframe for value-type value at 1x Budget
#                      benchmark_prior   RS - HB  HB - PB  RS - PB  cluster                  benchmark prior
# 99               lcbench-168330_bad  0.494917  -1.0000     -1.0        0             lcbench-168330   bad
# 189       lm1b_transformer_2048_bad  0.494917  -1.0000     -1.0        0      lm1b_transformer_2048   bad
# 171         imagenet_resnet_512_bad  0.494917  -1.0000     -1.0        0        imagenet_resnet_512   bad
# 153    cifar100_wideresnet_2048_bad  0.494917  -1.0000     -1.0        0   cifar100_wideresnet_2048   bad
# 135              lcbench-189906_bad  0.494917  -1.0000     -1.0        0             lcbench-189906   bad
# 117              lcbench-168910_bad  0.494917  -1.0000     -1.0        0             lcbench-168910   bad
# 81               lcbench-167190_bad  0.494917  -1.0000     -1.0        0             lcbench-167190   bad
# 207     translatewmt_xformer_64_bad  0.494917  -1.0000     -1.0        0    translatewmt_xformer_64   bad
# 45           jahs_fashion_mnist_bad  0.494917  -1.0000     -1.0        0         jahs_fashion_mnist   bad
# 27    jahs_colorectal_histology_bad  0.494917  -1.0000     -1.0        0  jahs_colorectal_histology   bad
# 9                  jahs_cifar10_bad  0.494917  -1.0000     -1.0        0               jahs_cifar10   bad
# 63               lcbench-126026_bad  0.494917  -1.0000     -1.0        0             lcbench-126026   bad
# 72              lcbench-167190_at25  0.494917   0.8355      1.0        1             lcbench-167190  at25
# 54              lcbench-126026_at25  0.494917   0.8355      1.0        1             lcbench-126026  at25
# 90              lcbench-168330_at25  0.494917   0.8355      1.0        1             lcbench-168330  at25
# 198    translatewmt_xformer_64_at25  0.494917   0.8355      1.0        1    translatewmt_xformer_64  at25
# 108             lcbench-168910_at25  0.494917   0.8355      1.0        1             lcbench-168910  at25
# 126             lcbench-189906_at25  0.494917   0.8355      1.0        1             lcbench-189906  at25
# 36          jahs_fashion_mnist_at25  0.494917   0.8355      1.0        1         jahs_fashion_mnist  at25
# 144   cifar100_wideresnet_2048_at25  0.494917   0.8355      1.0        1   cifar100_wideresnet_2048  at25
# 162        imagenet_resnet_512_at25  0.494917   0.8355      1.0        1        imagenet_resnet_512  at25
# 18   jahs_colorectal_histology_at25  0.494917   0.8355      1.0        1  jahs_colorectal_histology  at25
# 180      lm1b_transformer_2048_at25  0.494917   0.8355      1.0        1      lm1b_transformer_2048  at25
# 0                 jahs_cifar10_at25  0.494917   0.8355      1.0        1               jahs_cifar10  at25
#
# Dataframe for value-type value at 5x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 100              lcbench-168330_bad  0.777187 -0.533937  0.596125        0             lcbench-168330   bad
# 190       lm1b_transformer_2048_bad  0.777187 -0.533937  0.596125        0      lm1b_transformer_2048   bad
# 172         imagenet_resnet_512_bad  0.777187 -0.533937  0.596125        0        imagenet_resnet_512   bad
# 154    cifar100_wideresnet_2048_bad  0.777187 -0.533937  0.596125        0   cifar100_wideresnet_2048   bad
# 136              lcbench-189906_bad  0.777187 -0.533937  0.596125        0             lcbench-189906   bad
# 127             lcbench-189906_at25  0.777187 -0.533937  0.596125        0             lcbench-189906  at25
# 118              lcbench-168910_bad  0.777187 -0.533937  0.596125        0             lcbench-168910   bad
# 109             lcbench-168910_at25  0.777187 -0.533937  0.596125        0             lcbench-168910  at25
# 91              lcbench-168330_at25  0.777187 -0.533937  0.596125        0             lcbench-168330  at25
# 208     translatewmt_xformer_64_bad  0.777187 -0.533937  0.596125        0    translatewmt_xformer_64   bad
# 73              lcbench-167190_at25  0.777187 -0.533937  0.596125        0             lcbench-167190  at25
# 64               lcbench-126026_bad  0.777187 -0.533937  0.596125        0             lcbench-126026   bad
# 46           jahs_fashion_mnist_bad  0.777187 -0.533937  0.596125        0         jahs_fashion_mnist   bad
# 28    jahs_colorectal_histology_bad  0.777187 -0.533937  0.596125        0  jahs_colorectal_histology   bad
# 10                 jahs_cifar10_bad  0.777187 -0.533937  0.596125        0               jahs_cifar10   bad
# 82               lcbench-167190_bad  0.777187 -0.533937  0.596125        0             lcbench-167190   bad
# 199    translatewmt_xformer_64_at25  0.604375  0.823625  1.000000        1    translatewmt_xformer_64  at25
# 55              lcbench-126026_at25  0.604375  0.823625  1.000000        1             lcbench-126026  at25
# 37          jahs_fashion_mnist_at25  0.604375  0.823625  1.000000        1         jahs_fashion_mnist  at25
# 145   cifar100_wideresnet_2048_at25  0.604375  0.823625  1.000000        1   cifar100_wideresnet_2048  at25
# 163        imagenet_resnet_512_at25  0.604375  0.823625  1.000000        1        imagenet_resnet_512  at25
# 19   jahs_colorectal_histology_at25  0.604375  0.823625  1.000000        1  jahs_colorectal_histology  at25
# 181      lm1b_transformer_2048_at25  0.604375  0.823625  1.000000        1      lm1b_transformer_2048  at25
# 1                 jahs_cifar10_at25  0.604375  0.823625  1.000000        1               jahs_cifar10  at25
#
# Dataframe for value-type value at 12x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 101              lcbench-168330_bad  0.783900 -0.120400  0.709300        0             lcbench-168330   bad
# 191       lm1b_transformer_2048_bad  0.783900 -0.120400  0.709300        0      lm1b_transformer_2048   bad
# 173         imagenet_resnet_512_bad  0.783900 -0.120400  0.709300        0        imagenet_resnet_512   bad
# 155    cifar100_wideresnet_2048_bad  0.783900 -0.120400  0.709300        0   cifar100_wideresnet_2048   bad
# 137              lcbench-189906_bad  0.783900 -0.120400  0.709300        0             lcbench-189906   bad
# 74              lcbench-167190_at25  0.783900 -0.120400  0.709300        0             lcbench-167190  at25
# 65               lcbench-126026_bad  0.783900 -0.120400  0.709300        0             lcbench-126026   bad
# 209     translatewmt_xformer_64_bad  0.783900 -0.120400  0.709300        0    translatewmt_xformer_64   bad
# 47           jahs_fashion_mnist_bad  0.783900 -0.120400  0.709300        0         jahs_fashion_mnist   bad
# 11                 jahs_cifar10_bad  0.783900 -0.120400  0.709300        0               jahs_cifar10   bad
# 83               lcbench-167190_bad  0.852929  0.834143  0.998643        1             lcbench-167190   bad
# 92              lcbench-168330_at25  0.852929  0.834143  0.998643        1             lcbench-168330  at25
# 200    translatewmt_xformer_64_at25  0.852929  0.834143  0.998643        1    translatewmt_xformer_64  at25
# 110             lcbench-168910_at25  0.852929  0.834143  0.998643        1             lcbench-168910  at25
# 119              lcbench-168910_bad  0.852929  0.834143  0.998643        1             lcbench-168910   bad
# 128             lcbench-189906_at25  0.852929  0.834143  0.998643        1             lcbench-189906  at25
# 38          jahs_fashion_mnist_at25  0.852929  0.834143  0.998643        1         jahs_fashion_mnist  at25
# 146   cifar100_wideresnet_2048_at25  0.852929  0.834143  0.998643        1   cifar100_wideresnet_2048  at25
# 29    jahs_colorectal_histology_bad  0.852929  0.834143  0.998643        1  jahs_colorectal_histology   bad
# 164        imagenet_resnet_512_at25  0.852929  0.834143  0.998643        1        imagenet_resnet_512  at25
# 20   jahs_colorectal_histology_at25  0.852929  0.834143  0.998643        1  jahs_colorectal_histology  at25
# 182      lm1b_transformer_2048_at25  0.852929  0.834143  0.998643        1      lm1b_transformer_2048  at25
# 56              lcbench-126026_at25  0.852929  0.834143  0.998643        1             lcbench-126026  at25
# 2                 jahs_cifar10_at25  0.852929  0.834143  0.998643        1               jahs_cifar10  at25
#
# Dataframe for value-type regret at 1x Budget
#                      benchmark_prior   RS - HB  HB - PB  RS - PB  cluster                  benchmark prior
# 102              lcbench-168330_bad  0.494917  -1.0000     -1.0        0             lcbench-168330   bad
# 192       lm1b_transformer_2048_bad  0.494917  -1.0000     -1.0        0      lm1b_transformer_2048   bad
# 174         imagenet_resnet_512_bad  0.494917  -1.0000     -1.0        0        imagenet_resnet_512   bad
# 156    cifar100_wideresnet_2048_bad  0.494917  -1.0000     -1.0        0   cifar100_wideresnet_2048   bad
# 138              lcbench-189906_bad  0.494917  -1.0000     -1.0        0             lcbench-189906   bad
# 120              lcbench-168910_bad  0.494917  -1.0000     -1.0        0             lcbench-168910   bad
# 84               lcbench-167190_bad  0.494917  -1.0000     -1.0        0             lcbench-167190   bad
# 210     translatewmt_xformer_64_bad  0.494917  -1.0000     -1.0        0    translatewmt_xformer_64   bad
# 48           jahs_fashion_mnist_bad  0.494917  -1.0000     -1.0        0         jahs_fashion_mnist   bad
# 30    jahs_colorectal_histology_bad  0.494917  -1.0000     -1.0        0  jahs_colorectal_histology   bad
# 12                 jahs_cifar10_bad  0.494917  -1.0000     -1.0        0               jahs_cifar10   bad
# 66               lcbench-126026_bad  0.494917  -1.0000     -1.0        0             lcbench-126026   bad
# 75              lcbench-167190_at25  0.494917   0.8355      1.0        1             lcbench-167190  at25
# 57              lcbench-126026_at25  0.494917   0.8355      1.0        1             lcbench-126026  at25
# 93              lcbench-168330_at25  0.494917   0.8355      1.0        1             lcbench-168330  at25
# 201    translatewmt_xformer_64_at25  0.494917   0.8355      1.0        1    translatewmt_xformer_64  at25
# 111             lcbench-168910_at25  0.494917   0.8355      1.0        1             lcbench-168910  at25
# 129             lcbench-189906_at25  0.494917   0.8355      1.0        1             lcbench-189906  at25
# 39          jahs_fashion_mnist_at25  0.494917   0.8355      1.0        1         jahs_fashion_mnist  at25
# 147   cifar100_wideresnet_2048_at25  0.494917   0.8355      1.0        1   cifar100_wideresnet_2048  at25
# 165        imagenet_resnet_512_at25  0.494917   0.8355      1.0        1        imagenet_resnet_512  at25
# 21   jahs_colorectal_histology_at25  0.494917   0.8355      1.0        1  jahs_colorectal_histology  at25
# 183      lm1b_transformer_2048_at25  0.494917   0.8355      1.0        1      lm1b_transformer_2048  at25
# 3                 jahs_cifar10_at25  0.494917   0.8355      1.0        1               jahs_cifar10  at25
#
# Dataframe for value-type regret at 5x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 103              lcbench-168330_bad  0.777187 -0.533937  0.596125        0             lcbench-168330   bad
# 193       lm1b_transformer_2048_bad  0.777187 -0.533937  0.596125        0      lm1b_transformer_2048   bad
# 175         imagenet_resnet_512_bad  0.777187 -0.533937  0.596125        0        imagenet_resnet_512   bad
# 157    cifar100_wideresnet_2048_bad  0.777187 -0.533937  0.596125        0   cifar100_wideresnet_2048   bad
# 139              lcbench-189906_bad  0.777187 -0.533937  0.596125        0             lcbench-189906   bad
# 130             lcbench-189906_at25  0.777187 -0.533937  0.596125        0             lcbench-189906  at25
# 121              lcbench-168910_bad  0.777187 -0.533937  0.596125        0             lcbench-168910   bad
# 112             lcbench-168910_at25  0.777187 -0.533937  0.596125        0             lcbench-168910  at25
# 94              lcbench-168330_at25  0.777187 -0.533937  0.596125        0             lcbench-168330  at25
# 211     translatewmt_xformer_64_bad  0.777187 -0.533937  0.596125        0    translatewmt_xformer_64   bad
# 76              lcbench-167190_at25  0.777187 -0.533937  0.596125        0             lcbench-167190  at25
# 67               lcbench-126026_bad  0.777187 -0.533937  0.596125        0             lcbench-126026   bad
# 49           jahs_fashion_mnist_bad  0.777187 -0.533937  0.596125        0         jahs_fashion_mnist   bad
# 31    jahs_colorectal_histology_bad  0.777187 -0.533937  0.596125        0  jahs_colorectal_histology   bad
# 13                 jahs_cifar10_bad  0.777187 -0.533937  0.596125        0               jahs_cifar10   bad
# 85               lcbench-167190_bad  0.777187 -0.533937  0.596125        0             lcbench-167190   bad
# 202    translatewmt_xformer_64_at25  0.604375  0.823625  1.000000        1    translatewmt_xformer_64  at25
# 58              lcbench-126026_at25  0.604375  0.823625  1.000000        1             lcbench-126026  at25
# 40          jahs_fashion_mnist_at25  0.604375  0.823625  1.000000        1         jahs_fashion_mnist  at25
# 148   cifar100_wideresnet_2048_at25  0.604375  0.823625  1.000000        1   cifar100_wideresnet_2048  at25
# 166        imagenet_resnet_512_at25  0.604375  0.823625  1.000000        1        imagenet_resnet_512  at25
# 22   jahs_colorectal_histology_at25  0.604375  0.823625  1.000000        1  jahs_colorectal_histology  at25
# 184      lm1b_transformer_2048_at25  0.604375  0.823625  1.000000        1      lm1b_transformer_2048  at25
# 4                 jahs_cifar10_at25  0.604375  0.823625  1.000000        1               jahs_cifar10  at25
#
# Dataframe for value-type regret at 12x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 104              lcbench-168330_bad  0.789500 -0.129500  0.708800        0             lcbench-168330   bad
# 194       lm1b_transformer_2048_bad  0.789500 -0.129500  0.708800        0      lm1b_transformer_2048   bad
# 176         imagenet_resnet_512_bad  0.789500 -0.129500  0.708800        0        imagenet_resnet_512   bad
# 158    cifar100_wideresnet_2048_bad  0.789500 -0.129500  0.708800        0   cifar100_wideresnet_2048   bad
# 140              lcbench-189906_bad  0.789500 -0.129500  0.708800        0             lcbench-189906   bad
# 77              lcbench-167190_at25  0.789500 -0.129500  0.708800        0             lcbench-167190  at25
# 68               lcbench-126026_bad  0.789500 -0.129500  0.708800        0             lcbench-126026   bad
# 212     translatewmt_xformer_64_bad  0.789500 -0.129500  0.708800        0    translatewmt_xformer_64   bad
# 50           jahs_fashion_mnist_bad  0.789500 -0.129500  0.708800        0         jahs_fashion_mnist   bad
# 14                 jahs_cifar10_bad  0.789500 -0.129500  0.708800        0               jahs_cifar10   bad
# 86               lcbench-167190_bad  0.858357  0.834143  0.998643        1             lcbench-167190   bad
# 95              lcbench-168330_at25  0.858357  0.834143  0.998643        1             lcbench-168330  at25
# 203    translatewmt_xformer_64_at25  0.858357  0.834143  0.998643        1    translatewmt_xformer_64  at25
# 113             lcbench-168910_at25  0.858357  0.834143  0.998643        1             lcbench-168910  at25
# 122              lcbench-168910_bad  0.858357  0.834143  0.998643        1             lcbench-168910   bad
# 131             lcbench-189906_at25  0.858357  0.834143  0.998643        1             lcbench-189906  at25
# 41          jahs_fashion_mnist_at25  0.858357  0.834143  0.998643        1         jahs_fashion_mnist  at25
# 149   cifar100_wideresnet_2048_at25  0.858357  0.834143  0.998643        1   cifar100_wideresnet_2048  at25
# 32    jahs_colorectal_histology_bad  0.858357  0.834143  0.998643        1  jahs_colorectal_histology   bad
# 167        imagenet_resnet_512_at25  0.858357  0.834143  0.998643        1        imagenet_resnet_512  at25
# 23   jahs_colorectal_histology_at25  0.858357  0.834143  0.998643        1  jahs_colorectal_histology  at25
# 185      lm1b_transformer_2048_at25  0.858357  0.834143  0.998643        1      lm1b_transformer_2048  at25
# 59              lcbench-126026_at25  0.858357  0.834143  0.998643        1             lcbench-126026  at25
# 5                 jahs_cifar10_at25  0.858357  0.834143  0.998643        1               jahs_cifar10  at25
#
# Dataframe for value-type norm_regret at 1x Budget
#                      benchmark_prior   RS - HB  HB - PB  RS - PB  cluster                  benchmark prior
# 6                 jahs_cifar10_at25  0.494917   0.8355      1.0        0               jahs_cifar10  at25
# 24   jahs_colorectal_histology_at25  0.494917   0.8355      1.0        0  jahs_colorectal_histology  at25
# 186      lm1b_transformer_2048_at25  0.494917   0.8355      1.0        0      lm1b_transformer_2048  at25
# 42          jahs_fashion_mnist_at25  0.494917   0.8355      1.0        0         jahs_fashion_mnist  at25
# 60              lcbench-126026_at25  0.494917   0.8355      1.0        0             lcbench-126026  at25
# 168        imagenet_resnet_512_at25  0.494917   0.8355      1.0        0        imagenet_resnet_512  at25
# 78              lcbench-167190_at25  0.494917   0.8355      1.0        0             lcbench-167190  at25
# 96              lcbench-168330_at25  0.494917   0.8355      1.0        0             lcbench-168330  at25
# 204    translatewmt_xformer_64_at25  0.494917   0.8355      1.0        0    translatewmt_xformer_64  at25
# 114             lcbench-168910_at25  0.494917   0.8355      1.0        0             lcbench-168910  at25
# 150   cifar100_wideresnet_2048_at25  0.494917   0.8355      1.0        0   cifar100_wideresnet_2048  at25
# 132             lcbench-189906_at25  0.494917   0.8355      1.0        0             lcbench-189906  at25
# 195       lm1b_transformer_2048_bad  0.494917  -1.0000     -1.0        1      lm1b_transformer_2048   bad
# 177         imagenet_resnet_512_bad  0.494917  -1.0000     -1.0        1        imagenet_resnet_512   bad
# 159    cifar100_wideresnet_2048_bad  0.494917  -1.0000     -1.0        1   cifar100_wideresnet_2048   bad
# 105              lcbench-168330_bad  0.494917  -1.0000     -1.0        1             lcbench-168330   bad
# 123              lcbench-168910_bad  0.494917  -1.0000     -1.0        1             lcbench-168910   bad
# 87               lcbench-167190_bad  0.494917  -1.0000     -1.0        1             lcbench-167190   bad
# 69               lcbench-126026_bad  0.494917  -1.0000     -1.0        1             lcbench-126026   bad
# 51           jahs_fashion_mnist_bad  0.494917  -1.0000     -1.0        1         jahs_fashion_mnist   bad
# 33    jahs_colorectal_histology_bad  0.494917  -1.0000     -1.0        1  jahs_colorectal_histology   bad
# 15                 jahs_cifar10_bad  0.494917  -1.0000     -1.0        1               jahs_cifar10   bad
# 141              lcbench-189906_bad  0.494917  -1.0000     -1.0        1             lcbench-189906   bad
# 213     translatewmt_xformer_64_bad  0.494917  -1.0000     -1.0        1    translatewmt_xformer_64   bad
#
# Dataframe for value-type norm_regret at 5x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 7                 jahs_cifar10_at25  0.427556  0.718889  0.778111        0               jahs_cifar10  at25
# 25   jahs_colorectal_histology_at25  0.427556  0.718889  0.778111        0  jahs_colorectal_histology  at25
# 187      lm1b_transformer_2048_at25  0.427556  0.718889  0.778111        0      lm1b_transformer_2048  at25
# 43          jahs_fashion_mnist_at25  0.427556  0.718889  0.778111        0         jahs_fashion_mnist  at25
# 52           jahs_fashion_mnist_bad  0.427556  0.718889  0.778111        0         jahs_fashion_mnist   bad
# 61              lcbench-126026_at25  0.427556  0.718889  0.778111        0             lcbench-126026  at25
# 169        imagenet_resnet_512_at25  0.427556  0.718889  0.778111        0        imagenet_resnet_512  at25
# 151   cifar100_wideresnet_2048_at25  0.427556  0.718889  0.778111        0   cifar100_wideresnet_2048  at25
# 205    translatewmt_xformer_64_at25  0.427556  0.718889  0.778111        0    translatewmt_xformer_64  at25
# 196       lm1b_transformer_2048_bad  0.894800 -0.561600  0.702333        1      lm1b_transformer_2048   bad
# 178         imagenet_resnet_512_bad  0.894800 -0.561600  0.702333        1        imagenet_resnet_512   bad
# 160    cifar100_wideresnet_2048_bad  0.894800 -0.561600  0.702333        1   cifar100_wideresnet_2048   bad
# 142              lcbench-189906_bad  0.894800 -0.561600  0.702333        1             lcbench-189906   bad
# 133             lcbench-189906_at25  0.894800 -0.561600  0.702333        1             lcbench-189906  at25
# 106              lcbench-168330_bad  0.894800 -0.561600  0.702333        1             lcbench-168330   bad
# 115             lcbench-168910_at25  0.894800 -0.561600  0.702333        1             lcbench-168910  at25
# 97              lcbench-168330_at25  0.894800 -0.561600  0.702333        1             lcbench-168330  at25
# 88               lcbench-167190_bad  0.894800 -0.561600  0.702333        1             lcbench-167190   bad
# 79              lcbench-167190_at25  0.894800 -0.561600  0.702333        1             lcbench-167190  at25
# 70               lcbench-126026_bad  0.894800 -0.561600  0.702333        1             lcbench-126026   bad
# 34    jahs_colorectal_histology_bad  0.894800 -0.561600  0.702333        1  jahs_colorectal_histology   bad
# 16                 jahs_cifar10_bad  0.894800 -0.561600  0.702333        1               jahs_cifar10   bad
# 124              lcbench-168910_bad  0.894800 -0.561600  0.702333        1             lcbench-168910   bad
# 214     translatewmt_xformer_64_bad  0.894800 -0.561600  0.702333        1    translatewmt_xformer_64   bad
#
# Dataframe for value-type norm_regret at 12x Budget
#                      benchmark_prior   RS - HB   HB - PB   RS - PB  cluster                  benchmark prior
# 8                 jahs_cifar10_at25  0.852929  0.834143  0.998643        0               jahs_cifar10  at25
# 134             lcbench-189906_at25  0.852929  0.834143  0.998643        0             lcbench-189906  at25
# 125              lcbench-168910_bad  0.852929  0.834143  0.998643        0             lcbench-168910   bad
# 116             lcbench-168910_at25  0.852929  0.834143  0.998643        0             lcbench-168910  at25
# 206    translatewmt_xformer_64_at25  0.852929  0.834143  0.998643        0    translatewmt_xformer_64  at25
# 98              lcbench-168330_at25  0.852929  0.834143  0.998643        0             lcbench-168330  at25
# 89               lcbench-167190_bad  0.852929  0.834143  0.998643        0             lcbench-167190   bad
# 170        imagenet_resnet_512_at25  0.852929  0.834143  0.998643        0        imagenet_resnet_512  at25
# 62              lcbench-126026_at25  0.852929  0.834143  0.998643        0             lcbench-126026  at25
# 188      lm1b_transformer_2048_at25  0.852929  0.834143  0.998643        0      lm1b_transformer_2048  at25
# 44          jahs_fashion_mnist_at25  0.852929  0.834143  0.998643        0         jahs_fashion_mnist  at25
# 35    jahs_colorectal_histology_bad  0.852929  0.834143  0.998643        0  jahs_colorectal_histology   bad
# 26   jahs_colorectal_histology_at25  0.852929  0.834143  0.998643        0  jahs_colorectal_histology  at25
# 152   cifar100_wideresnet_2048_at25  0.852929  0.834143  0.998643        0   cifar100_wideresnet_2048  at25
# 161    cifar100_wideresnet_2048_bad  0.783900 -0.120400  0.709300        1   cifar100_wideresnet_2048   bad
# 197       lm1b_transformer_2048_bad  0.783900 -0.120400  0.709300        1      lm1b_transformer_2048   bad
# 179         imagenet_resnet_512_bad  0.783900 -0.120400  0.709300        1        imagenet_resnet_512   bad
# 107              lcbench-168330_bad  0.783900 -0.120400  0.709300        1             lcbench-168330   bad
# 80              lcbench-167190_at25  0.783900 -0.120400  0.709300        1             lcbench-167190  at25
# 71               lcbench-126026_bad  0.783900 -0.120400  0.709300        1             lcbench-126026   bad
# 53           jahs_fashion_mnist_bad  0.783900 -0.120400  0.709300        1         jahs_fashion_mnist   bad
# 17                 jahs_cifar10_bad  0.783900 -0.120400  0.709300        1               jahs_cifar10   bad
# 143              lcbench-189906_bad  0.783900 -0.120400  0.709300        1             lcbench-189906   bad
# 215     translatewmt_xformer_64_bad  0.783900 -0.120400  0.709300        1    translatewmt_xformer_64   bad
