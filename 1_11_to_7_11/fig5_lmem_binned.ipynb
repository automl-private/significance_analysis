# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tabulate
from scipy import stats
from autorank import autorank,create_report,plot_stats
pd.set_option("chained_assignment", None)
pd.set_option("display.max_rows", 5000)
pd.set_option("display.max_columns", 5000)
pd.set_option("display.width", 10000)

def load_priorband_data():
    df = pd.read_parquet("data_for_anton.parquet")
    df=df.reset_index()
    df_collection=[]
    for seed_nr in range(50):
        partial_df=df[["benchmark","prior","algorithm","used_fidelity"]]
        partial_df["value"]=df[f"seed-{seed_nr}"]
        partial_df["seed"]=seed_nr
        df_collection.append(partial_df)
        print(f"Seed {seed_nr+1}/50", end="\r", flush=True)
    df_complete=pd.concat(df_collection,ignore_index=True)
    df_complete[["value","used_fidelity"]]=df_complete[["value","used_fidelity"]].astype(float)
    return df_complete

df=load_priorband_data()
# Out:
# Seed 50/50

# %%
algo_dict={"rs_hb_pb":["random_search","hyperband","pb_mutation_dynamic_geometric-default-at-target"]}
#algo_dict["fig7"]=["random_search_prior","bo","bohb","priorband_bo"]
prior_dict={"good+bad":["at25","bad"]}
benchmarks=["jahs_cifar10","jahs_colorectal_histology","jahs_fashion_mnist","lcbench-126026","lcbench-167190","lcbench-168330","lcbench-168910","lcbench-189906","cifar100_wideresnet_2048","imagenet_resnet_512","lm1b_transformer_2048","translatewmt_xformer_64"]
label_dict={'random_search': 'RS', 'hyperband': 'HB', 'pb_mutation_dynamic_geometric-default-at-target': 'PB', 'jahs_cifar10': 'JAHS-C10', 'jahs_colorectal_histology': 'JAHS-CH', 'jahs_fashion_mnist': 'JAHS-FM', 'lcbench-126026': 'LC-126026', 'lcbench-167190': 'LC-167190', 'lcbench-168330': 'LC-168330', 'lcbench-168910': 'LC-168910', 'lcbench-189906': 'LC-189906', 'cifar100_wideresnet_2048': 'PD1-Cifar100', 'imagenet_resnet_512': 'PD1-ImageNet', 'lm1b_transformer_2048': 'PD1-LM1B', 'translatewmt_xformer_64': 'PD1-WMT',"random_search_prior":"RS+Prior","bo":"BO","pibo":"PiBO","bohb":"BOHB","priorband_bo":"PriorBand+BO"}


for priortype in df["prior"].unique():
    prior_dict[priortype]=[priortype]


df_dict={}
for prior_key,prior_value in prior_dict.items():
    df_dict[prior_key]={}
    for b_n,benchmark in enumerate(benchmarks):
        print(f"Prior {prior_key}, Benchmark {b_n+1}/{len(benchmarks)}      ", end="\r", flush=True)
        df_dict[prior_key][benchmark]={}
        for algo_key,algo_value in algo_dict.items():
            df_dict[prior_key][benchmark][algo_key]=df.loc[(df["prior"].isin(prior_value))&(df["algorithm"].isin(algo_value))&(df["benchmark"]==benchmark)].reset_index(drop=True)
# Out:
# Prior medium, Benchmark 12/12

# %%
def create_lmem_incumbent(priors:list[str],fs,algorithms:list[str],algo_group:str,benchmarks:list[str],df_dict:pd.DataFrame):
    output={}
    output["dataset"]={}
    output["mean_std"]={}
    for p_n,prior in enumerate(priors):
        output["dataset"][prior]=pd.DataFrame()
        output["mean_std"][prior]={}
        for n_f,max_f in enumerate(fs):
            labels=[]
            for algo in algorithms:
                labels.append(label_dict[algo])
            output["mean_std"][prior][max_f]=pd.DataFrame(columns=["benchmark"]+labels)
            for b_n,benchmark in enumerate(benchmarks):
                df_at_point=df_dict[prior][benchmark][algo_group]
                df_at_point=df_at_point.loc[df_at_point["used_fidelity"]<=max_f]
                for seed in df_at_point["seed"].unique():
                    print(f"Prior {prior} ({p_n+1}), Fidelity {n_f+1}/{len(fs)}, Benchmark {b_n+1}/{len(benchmarks)}          ", end="\r", flush=True)
                    for algo in algorithms:
                        df_criteria=df_at_point.loc[(df_at_point["seed"]==seed)&(df_at_point["algorithm"]==algo)].iloc[-1].to_frame().T
                        df_criteria["used_fidelity"]=max_f
                        output["dataset"][prior]=pd.concat([output["dataset"][prior],df_criteria],ignore_index=True)
            output["dataset"][prior][["value","used_fidelity"]]=output["dataset"][prior][["value","used_fidelity"]].astype(float)
            output["dataset"][prior]["seed"]=output["dataset"][prior]["seed"].astype(int)
            
    return output["dataset"]

# %%
from significance_analysis import conduct_analysis

fig5={}
fig5["algo_group"]="rs_hb_pb"
fig5["algorithms"]=algo_dict[fig5["algo_group"]].copy()
fig5["priors"]=["good+bad","at25","bad"]
fig5["benchmarks"]=benchmarks
fig5["max_f"]=np.linspace(1,12,20).tolist()

fig5["dataset"]=create_lmem_incumbent(fig5["priors"],fig5["max_f"],fig5["algorithms"],fig5["algo_group"],fig5["benchmarks"],df_dict)
# Out:
# Prior bad (3), Fidelity 20/20, Benchmark 12/12

# %%
result_dict={}
for p_n,priortype in enumerate(fig5["priors"]):
    print(f"Prior {priortype} ({p_n+1})")
    #fig5["dataset"][priortype]=fig5["dataset"][priortype].replace({"algorithm": label_dict,"benchmark": label_dict})
    result_dict[priortype]=conduct_analysis(fig5["dataset"][priortype],"value","algorithm","benchmark","used_fidelity",fidelity="used_fidelity",continuous_fidelity=True,show_plots=True,verbosity=1)[1]
print("Done")
# Out:
# Prior good+bad (1)
# P-value: 0.0
#
# As the p-value 0.0 is smaller than 0.05, we can reject the Null-Hypothesis that the model that does not consider the algorithm and the used_fidelity describes the data as well as the one that does. Therefore there is significant difference within algorithm and the used_fidelity.
#
# P-values adjusted by tukey method for family of 3 estimates
# The best performing algorithm in used_fidelity-class 1.0 is random_search, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 1.5789473684210527 is random_search, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 2.1578947368421053 is random_search, but ['hyperband'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 2.736842105263158 is hyperband, but ['random_search'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 3.3157894736842106 is hyperband, but ['random_search'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 3.8947368421052633 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 4.473684210526316 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 5.052631578947368 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 5.631578947368421 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 6.210526315789474 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 6.7894736842105265 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 7.368421052631579 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 7.947368421052632 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 8.526315789473685 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.105263157894736 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.68421052631579 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.263157894736842 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.842105263157896 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 11.421052631578949 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
#         algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 1   random_search                 1.0   -52.355 -56.658  -48.052  2.159  73.414
# 4   random_search  1.5789473684210527   -43.922 -47.861  -39.983  1.961  49.987
# 7   random_search  2.1578947368421053   -37.698 -41.413  -33.983  1.836  38.389
# 10  random_search   2.736842105263158   -31.783 -35.300  -28.266  1.721  29.663
# 13  random_search  3.3157894736842106   -25.559 -28.907  -22.211  1.619  23.248
# 16  random_search  3.8947368421052633   -19.488 -22.701  -16.276  1.533  18.677
# 19  random_search   4.473684210526316   -13.322 -16.435  -10.209  1.465  15.577
# 22  random_search   5.052631578947368    -7.098 -10.146   -4.049  1.418  13.667
# 25  random_search   5.631578947368421    -0.922  -3.939    2.095  1.394  12.758
# 28  random_search   6.210526315789474     5.302   2.285    8.319  1.394  12.758
# 31  random_search  6.7894736842105265    11.497   8.449   14.545  1.418  13.667
# 34  random_search   7.368421052631579    17.721  14.608   20.834  1.465  15.577
# 37  random_search   7.947368421052632    23.914  20.701   27.126  1.533  18.677
# 40  random_search   8.526315789473685    30.111  26.763   33.459  1.619  23.248
# 43  random_search   9.105263157894736    36.335  32.818   39.852  1.721  29.663
# 46  random_search    9.68421052631579    42.530  38.815   46.245  1.836  38.389
# 49  random_search  10.263157894736842    48.754  44.815   52.693  1.961  49.987
# 52  random_search  10.842105263157896    54.956  50.771   59.140  2.095  65.108
# 55  random_search  11.421052631578949    61.171  56.724   65.618  2.236  84.492
#     algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 2   hyperband                 1.0   -50.114 -54.417  -45.811  2.159  73.414
# 5   hyperband  1.5789473684210527   -43.166 -47.105  -39.227  1.961  49.987
# 8   hyperband  2.1578947368421053   -36.986 -40.701  -33.271  1.836  38.389
# 11  hyperband   2.736842105263158   -32.047 -35.564  -28.530  1.721  29.663
# 14  hyperband  3.3157894736842106   -25.827 -29.175  -22.479  1.619  23.248
# 17  hyperband  3.8947368421052633   -19.607 -22.820  -16.394  1.533  18.677
# 20  hyperband   4.473684210526316   -13.387 -16.500  -10.275  1.465  15.577
# 23  hyperband   5.052631578947368    -7.257 -10.305   -4.209  1.418  13.667
# 26  hyperband   5.631578947368421    -1.034  -4.050    1.983  1.394  12.758
# 29  hyperband   6.210526315789474     5.190   2.173    8.207  1.394  12.758
# 32  hyperband  6.7894736842105265    11.414   8.365   14.462  1.418  13.667
# 35  hyperband   7.368421052631579    17.588  14.475   20.700  1.465  15.577
# 38  hyperband   7.947368421052632    23.812  20.599   27.024  1.533  18.677
# 41  hyperband   8.526315789473685    30.016  26.668   33.364  1.619  23.248
# 44  hyperband   9.105263157894736    36.226  32.709   39.742  1.721  29.663
# 47  hyperband    9.68421052631579    42.449  38.734   46.164  1.836  38.389
# 50  hyperband  10.263157894736842    48.669  44.730   52.608  1.961  49.987
# 53  hyperband  10.842105263157896    54.892  50.708   59.077  2.095  65.108
# 56  hyperband  11.421052631578949    61.108  56.661   65.554  2.236  84.492
#                                           algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 3   pb_mutation_dynamic_geometric-default-at-target                 1.0   -40.165 -44.468  -35.863  2.159  73.414
# 6   pb_mutation_dynamic_geometric-default-at-target  1.5789473684210527   -41.492 -45.431  -37.553  1.961  49.987
# 9   pb_mutation_dynamic_geometric-default-at-target  2.1578947368421053   -35.404 -39.119  -31.689  1.836  38.389
# 12  pb_mutation_dynamic_geometric-default-at-target   2.736842105263158   -30.629 -34.146  -27.112  1.721  29.663
# 15  pb_mutation_dynamic_geometric-default-at-target  3.3157894736842106   -24.416 -27.764  -21.068  1.619  23.248
# 18  pb_mutation_dynamic_geometric-default-at-target  3.8947368421052633   -19.522 -22.735  -16.310  1.533  18.677
# 21  pb_mutation_dynamic_geometric-default-at-target   4.473684210526316   -13.305 -16.417  -10.192  1.465  15.577
# 24  pb_mutation_dynamic_geometric-default-at-target   5.052631578947368    -7.092 -10.140   -4.044  1.418  13.667
# 27  pb_mutation_dynamic_geometric-default-at-target   5.631578947368421    -0.872  -3.889    2.145  1.394  12.758
# 30  pb_mutation_dynamic_geometric-default-at-target   6.210526315789474     5.181   2.164    8.198  1.394  12.758
# 33  pb_mutation_dynamic_geometric-default-at-target  6.7894736842105265    11.404   8.356   14.453  1.418  13.667
# 36  pb_mutation_dynamic_geometric-default-at-target   7.368421052631579    17.628  14.515   20.740  1.465  15.577
# 39  pb_mutation_dynamic_geometric-default-at-target   7.947368421052632    23.847  20.635   27.060  1.533  18.677
# 42  pb_mutation_dynamic_geometric-default-at-target   8.526315789473685    30.005  26.657   33.353  1.619  23.248
# 45  pb_mutation_dynamic_geometric-default-at-target   9.105263157894736    36.210  32.693   39.726  1.721  29.663
# 48  pb_mutation_dynamic_geometric-default-at-target    9.68421052631579    42.432  38.716   46.147  1.836  38.389
# 51  pb_mutation_dynamic_geometric-default-at-target  10.263157894736842    48.647  44.708   52.587  1.961  49.987
# 54  pb_mutation_dynamic_geometric-default-at-target  10.842105263157896    54.870  50.686   59.055  2.095  65.108
# 57  pb_mutation_dynamic_geometric-default-at-target  11.421052631578949    61.089  56.642   65.536  2.236  84.492
# Prior at25 (2)
# P-value: 0.0
#
# As the p-value 0.0 is smaller than 0.05, we can reject the Null-Hypothesis that the model that does not consider the algorithm and the used_fidelity describes the data as well as the one that does. Therefore there is significant difference within algorithm and the used_fidelity.
#
# P-values adjusted by tukey method for family of 3 estimates
# The best performing algorithm in used_fidelity-class 1.0 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 1.5789473684210527 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 2.1578947368421053 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 2.736842105263158 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 3.3157894736842106 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 3.8947368421052633 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 4.473684210526316 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 5.052631578947368 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 5.631578947368421 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 6.210526315789474 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 6.7894736842105265 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 7.368421052631579 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 7.947368421052632 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 8.526315789473685 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.105263157894736 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.68421052631579 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.263157894736842 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.842105263157896 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 11.421052631578949 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
#         algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 1   random_search                 1.0    -2.512  -5.032    0.007  1.210  20.421
# 4   random_search  1.5789473684210527    -2.387  -4.842    0.069  1.167  17.717
# 7   random_search  2.1578947368421053    -1.701  -4.119    0.717  1.142  16.229
# 10  random_search   2.736842105263158    -1.324  -3.710    1.063  1.120  15.005
# 13  random_search  3.3157894736842106    -0.637  -2.999    1.724  1.101  14.022
# 16  random_search  3.8947368421052633    -0.105  -2.446    2.236  1.086  13.260
# 19  random_search   4.473684210526316     0.523  -1.803    2.849  1.074  12.702
# 22  random_search   5.052631578947368     1.209  -1.107    3.526  1.066  12.336
# 25  random_search   5.631578947368421     1.847  -0.464    4.159  1.062  12.156
# 28  random_search   6.210526315789474     2.533   0.222    4.845  1.062  12.156
# 31  random_search  6.7894736842105265     3.190   0.873    5.506  1.066  12.336
# 34  random_search   7.368421052631579     3.876   1.550    6.202  1.074  12.702
# 37  random_search   7.947368421052632     4.530   2.189    6.871  1.086  13.260
# 40  random_search   8.526315789473685     5.190   2.829    7.551  1.101  14.022
# 43  random_search   9.105263157894736     5.876   3.489    8.263  1.120  15.006
# 46  random_search    9.68421052631579     6.532   4.114    8.951  1.142  16.230
# 49  random_search  10.263157894736842     7.218   4.763    9.674  1.167  17.718
# 52  random_search  10.842105263157896     7.882   5.384   10.380  1.196  19.499
# 55  random_search  11.421052631578949     8.559   6.013   11.106  1.227  21.605
#     algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 2   hyperband                 1.0    -0.272  -2.791    2.248  1.210  20.421
# 5   hyperband  1.5789473684210527    -1.630  -4.085    0.825  1.167  17.717
# 8   hyperband  2.1578947368421053    -0.989  -3.407    1.430  1.142  16.229
# 11  hyperband   2.736842105263158    -1.588  -3.974    0.799  1.120  15.005
# 14  hyperband  3.3157894736842106    -0.906  -3.267    1.455  1.101  14.022
# 17  hyperband  3.8947368421052633    -0.224  -2.565    2.117  1.086  13.260
# 20  hyperband   4.473684210526316     0.458  -1.868    2.784  1.074  12.702
# 23  hyperband   5.052631578947368     1.050  -1.266    3.366  1.066  12.336
# 26  hyperband   5.631578947368421     1.735  -0.576    4.047  1.062  12.156
# 29  hyperband   6.210526315789474     2.421   0.109    4.732  1.062  12.156
# 32  hyperband  6.7894736842105265     3.106   0.790    5.423  1.066  12.336
# 35  hyperband   7.368421052631579     3.743   1.416    6.069  1.074  12.702
# 38  hyperband   7.947368421052632     4.428   2.087    6.769  1.086  13.260
# 41  hyperband   8.526315789473685     5.094   2.733    7.455  1.101  14.022
# 44  hyperband   9.105263157894736     5.766   3.379    8.153  1.120  15.006
# 47  hyperband    9.68421052631579     6.451   4.033    8.870  1.142  16.230
# 50  hyperband  10.263157894736842     7.133   4.678    9.589  1.167  17.718
# 53  hyperband  10.842105263157896     7.819   5.321   10.317  1.196  19.499
# 56  hyperband  11.421052631578949     8.496   5.949   11.043  1.227  21.605
#                                           algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 3   pb_mutation_dynamic_geometric-default-at-target                 1.0    -4.127  -6.647   -1.608  1.210  20.421
# 6   pb_mutation_dynamic_geometric-default-at-target  1.5789473684210527    -3.100  -5.556   -0.645  1.167  17.717
# 9   pb_mutation_dynamic_geometric-default-at-target  2.1578947368421053    -2.417  -4.835    0.002  1.142  16.229
# 12  pb_mutation_dynamic_geometric-default-at-target   2.736842105263158    -1.731  -4.118    0.656  1.120  15.005
# 15  pb_mutation_dynamic_geometric-default-at-target  3.3157894736842106    -1.049  -3.410    1.312  1.101  14.022
# 18  pb_mutation_dynamic_geometric-default-at-target  3.8947368421052633    -0.433  -2.774    1.908  1.086  13.260
# 21  pb_mutation_dynamic_geometric-default-at-target   4.473684210526316     0.252  -2.074    2.578  1.074  12.702
# 24  pb_mutation_dynamic_geometric-default-at-target   5.052631578947368     0.938  -1.378    3.254  1.066  12.336
# 27  pb_mutation_dynamic_geometric-default-at-target   5.631578947368421     1.621  -0.690    3.933  1.062  12.156
# 30  pb_mutation_dynamic_geometric-default-at-target   6.210526315789474     2.279  -0.032    4.591  1.062  12.156
# 33  pb_mutation_dynamic_geometric-default-at-target  6.7894736842105265     2.965   0.649    5.282  1.066  12.336
# 36  pb_mutation_dynamic_geometric-default-at-target   7.368421052631579     3.651   1.325    5.977  1.074  12.702
# 39  pb_mutation_dynamic_geometric-default-at-target   7.947368421052632     4.335   1.994    6.676  1.086  13.260
# 42  pb_mutation_dynamic_geometric-default-at-target   8.526315789473685     4.993   2.632    7.354  1.101  14.022
# 45  pb_mutation_dynamic_geometric-default-at-target   9.105263157894736     5.669   3.283    8.056  1.120  15.006
# 48  pb_mutation_dynamic_geometric-default-at-target    9.68421052631579     6.355   3.936    8.773  1.142  16.230
# 51  pb_mutation_dynamic_geometric-default-at-target  10.263157894736842     7.031   4.576    9.486  1.167  17.718
# 54  pb_mutation_dynamic_geometric-default-at-target  10.842105263157896     7.717   5.218   10.215  1.196  19.499
# 57  pb_mutation_dynamic_geometric-default-at-target  11.421052631578949     8.400   5.853   10.946  1.227  21.605
# Prior bad (3)
# P-value: 0.0
#
# As the p-value 0.0 is smaller than 0.05, we can reject the Null-Hypothesis that the model that does not consider the algorithm and the used_fidelity describes the data as well as the one that does. Therefore there is significant difference within algorithm and the used_fidelity.
#
# P-values adjusted by tukey method for family of 3 estimates
# The best performing algorithm in used_fidelity-class 1.0 is random_search, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 1.5789473684210527 is random_search, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 2.1578947368421053 is random_search, but ['hyperband'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 2.736842105263158 is hyperband, but ['random_search'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 3.3157894736842106 is hyperband, but ['random_search'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 3.8947368421052633 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 4.473684210526316 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 5.052631578947368 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 5.631578947368421 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 6.210526315789474 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 6.7894736842105265 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 7.368421052631579 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 7.947368421052632 is hyperband, but ['random_search', '(pb_mutation_dynamic_geometric-default-at-target)'] are only insignificantly worse.
#
# The best performing algorithm in used_fidelity-class 8.526315789473685 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.105263157894736 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 9.68421052631579 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.263157894736842 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 10.842105263157896 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
# The best performing algorithm in used_fidelity-class 11.421052631578949 is pb_mutation_dynamic_geometric-default-at-target, all others perform significantly worse.
#
#         algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 1   random_search                 1.0   -52.608 -56.900  -48.316  2.154  73.041
# 4   random_search  1.5789473684210527   -44.133 -48.063  -40.203  1.957  49.770
# 7   random_search  2.1578947368421053   -37.881 -41.588  -34.173  1.832  38.245
# 10  random_search   2.736842105263158   -31.937 -35.447  -28.427  1.718  29.571
# 13  random_search  3.3157894736842106   -25.685 -29.027  -22.343  1.616  23.192
# 16  random_search  3.8947368421052633   -19.587 -22.794  -16.379  1.531  18.646
# 19  random_search   4.473684210526316   -13.392 -16.500  -10.284  1.463  15.561
# 22  random_search   5.052631578947368    -7.140 -10.184   -4.096  1.416  13.660
# 25  random_search   5.631578947368421    -0.936  -3.949    2.077  1.392  12.755
# 28  random_search   6.210526315789474     5.316   2.303    8.329  1.392  12.755
# 31  random_search  6.7894736842105265    11.539   8.495   14.583  1.416  13.660
# 34  random_search   7.368421052631579    17.791  14.683   20.900  1.463  15.561
# 37  random_search   7.947368421052632    24.012  20.804   27.220  1.531  18.646
# 40  random_search   8.526315789473685    30.237  26.895   33.580  1.616  23.192
# 43  random_search   9.105263157894736    36.490  32.980   40.000  1.718  29.571
# 46  random_search    9.68421052631579    42.712  39.005   46.420  1.832  38.245
# 49  random_search  10.263157894736842    48.965  45.034   52.895  1.957  49.770
# 52  random_search  10.842105263157896    55.194  51.020   59.369  2.090  64.791
# 55  random_search  11.421052631578949    61.438  57.002   65.873  2.231  84.043
#     algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 2   hyperband                 1.0   -50.367 -54.659  -46.075  2.154  73.041
# 5   hyperband  1.5789473684210527   -43.376 -47.306  -39.446  1.957  49.770
# 8   hyperband  2.1578947368421053   -37.169 -40.876  -33.461  1.832  38.245
# 11  hyperband   2.736842105263158   -32.201 -35.711  -28.691  1.718  29.571
# 14  hyperband  3.3157894736842106   -25.954 -29.296  -22.611  1.616  23.192
# 17  hyperband  3.8947368421052633   -19.705 -22.913  -16.498  1.531  18.646
# 20  hyperband   4.473684210526316   -13.458 -16.566  -10.349  1.463  15.561
# 23  hyperband   5.052631578947368    -7.299 -10.343   -4.255  1.416  13.660
# 26  hyperband   5.631578947368421    -1.048  -4.061    1.965  1.392  12.755
# 29  hyperband   6.210526315789474     5.204   2.191    8.217  1.392  12.755
# 32  hyperband  6.7894736842105265    11.456   8.412   14.500  1.416  13.660
# 35  hyperband   7.368421052631579    17.658  14.550   20.766  1.463  15.561
# 38  hyperband   7.947368421052632    23.910  20.702   27.118  1.531  18.646
# 41  hyperband   8.526315789473685    30.142  26.800   33.484  1.616  23.192
# 44  hyperband   9.105263157894736    36.380  32.870   39.890  1.718  29.571
# 47  hyperband    9.68421052631579    42.631  38.924   46.339  1.832  38.245
# 50  hyperband  10.263157894736842    48.879  44.949   52.810  1.957  49.770
# 53  hyperband  10.842105263157896    55.131  50.957   59.305  2.090  64.791
# 56  hyperband  11.421052631578949    61.374  56.939   65.810  2.231  84.043
#                                           algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 3   pb_mutation_dynamic_geometric-default-at-target                 1.0   -40.186 -44.478  -35.894  2.154  73.041
# 6   pb_mutation_dynamic_geometric-default-at-target  1.5789473684210527   -41.673 -45.603  -37.743  1.957  49.770
# 9   pb_mutation_dynamic_geometric-default-at-target  2.1578947368421053   -35.566 -39.273  -31.859  1.832  38.245
# 12  pb_mutation_dynamic_geometric-default-at-target   2.736842105263158   -30.766 -34.276  -27.256  1.718  29.571
# 15  pb_mutation_dynamic_geometric-default-at-target  3.3157894736842106   -24.530 -27.872  -21.187  1.616  23.192
# 18  pb_mutation_dynamic_geometric-default-at-target  3.8947368421052633   -19.610 -22.818  -16.402  1.531  18.646
# 21  pb_mutation_dynamic_geometric-default-at-target   4.473684210526316   -13.366 -16.474  -10.258  1.463  15.561
# 24  pb_mutation_dynamic_geometric-default-at-target   5.052631578947368    -7.125 -10.169   -4.081  1.416  13.660
# 27  pb_mutation_dynamic_geometric-default-at-target   5.631578947368421    -0.878  -3.891    2.135  1.392  12.755
# 30  pb_mutation_dynamic_geometric-default-at-target   6.210526315789474     5.203   2.190    8.216  1.392  12.755
# 33  pb_mutation_dynamic_geometric-default-at-target  6.7894736842105265    11.454   8.410   14.498  1.416  13.660
# 36  pb_mutation_dynamic_geometric-default-at-target   7.368421052631579    17.705  14.596   20.813  1.463  15.561
# 39  pb_mutation_dynamic_geometric-default-at-target   7.947368421052632    23.953  20.745   27.160  1.531  18.646
# 42  pb_mutation_dynamic_geometric-default-at-target   8.526315789473685    30.138  26.795   33.480  1.616  23.192
# 45  pb_mutation_dynamic_geometric-default-at-target   9.105263157894736    36.371  32.861   39.881  1.718  29.571
# 48  pb_mutation_dynamic_geometric-default-at-target    9.68421052631579    42.619  38.912   46.327  1.832  38.245
# 51  pb_mutation_dynamic_geometric-default-at-target  10.263157894736842    48.863  44.933   52.793  1.957  49.770
# 54  pb_mutation_dynamic_geometric-default-at-target  10.842105263157896    55.114  50.940   59.288  2.090  64.791
# 57  pb_mutation_dynamic_geometric-default-at-target  11.421052631578949    61.360  56.924   65.796  2.231  84.043
# Done

# %%
print(result_dict["bad"])
# Out:
# (                                          algorithm  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE      DF
# 1                                     random_search                 1.0     3.662   0.409    6.916  1.553  18.803
# 2                                         hyperband                 1.0     5.903   2.650    9.157  1.553  18.803
# 3   pb_mutation_dynamic_geometric-default-at-target                 1.0    16.084  12.830   19.337  1.553  18.803
# 4                                     random_search  1.5789473684210527     2.759  -0.777    6.295  1.716  24.655
# 5                                         hyperband  1.5789473684210527     3.515  -0.021    7.051  1.716  24.655
# 6   pb_mutation_dynamic_geometric-default-at-target  1.5789473684210527     5.219   1.683    8.755  1.716  24.655
# 7                                     random_search  2.1578947368421053     2.759  -0.777    6.295  1.716  24.655
# 8                                         hyperband  2.1578947368421053     3.471  -0.065    7.007  1.716  24.655
# 9   pb_mutation_dynamic_geometric-default-at-target  2.1578947368421053     5.073   1.537    8.609  1.716  24.655
# 10                                    random_search   2.736842105263158     2.450  -1.086    5.986  1.716  24.655
# 11                                        hyperband   2.736842105263158     2.186  -1.350    5.722  1.716  24.655
# 12  pb_mutation_dynamic_geometric-default-at-target   2.736842105263158     3.622   0.086    7.158  1.716  24.655
# 13                                    random_search  3.3157894736842106     2.450  -1.086    5.986  1.716  24.655
# 14                                        hyperband  3.3157894736842106     2.181  -1.355    5.717  1.716  24.655
# 15  pb_mutation_dynamic_geometric-default-at-target  3.3157894736842106     3.605   0.069    7.141  1.716  24.655
# 16                                    random_search  3.8947368421052633     2.296  -1.240    5.832  1.716  24.655
# 17                                        hyperband  3.8947368421052633     2.177  -1.359    5.713  1.716  24.655
# 18  pb_mutation_dynamic_geometric-default-at-target  3.8947368421052633     2.273  -1.263    5.809  1.716  24.655
# 19                                    random_search   4.473684210526316     2.239  -1.297    5.775  1.716  24.655
# 20                                        hyperband   4.473684210526316     2.173  -1.363    5.709  1.716  24.655
# 21  pb_mutation_dynamic_geometric-default-at-target   4.473684210526316     2.264  -1.272    5.800  1.716  24.655
# 22                                    random_search   5.052631578947368     2.239  -1.297    5.775  1.716  24.655
# 23                                        hyperband   5.052631578947368     2.079  -1.457    5.615  1.716  24.655
# 24  pb_mutation_dynamic_geometric-default-at-target   5.052631578947368     2.253  -1.283    5.789  1.716  24.655
# 25                                    random_search   5.631578947368421     2.190  -1.346    5.726  1.716  24.655
# 26                                        hyperband   5.631578947368421     2.078  -1.458    5.615  1.716  24.655
# 27  pb_mutation_dynamic_geometric-default-at-target   5.631578947368421     2.248  -1.288    5.784  1.716  24.655
# 28                                    random_search   6.210526315789474     2.190  -1.346    5.726  1.716  24.655
# 29                                        hyperband   6.210526315789474     2.078  -1.458    5.614  1.716  24.655
# 30  pb_mutation_dynamic_geometric-default-at-target   6.210526315789474     2.077  -1.459    5.613  1.716  24.655
# 31                                    random_search  6.7894736842105265     2.161  -1.375    5.697  1.716  24.655
# 32                                        hyperband  6.7894736842105265     2.077  -1.459    5.613  1.716  24.655
# 33  pb_mutation_dynamic_geometric-default-at-target  6.7894736842105265     2.076  -1.460    5.612  1.716  24.655
# 34                                    random_search   7.368421052631579     2.161  -1.375    5.697  1.716  24.655
# 35                                        hyperband   7.368421052631579     2.027  -1.509    5.563  1.716  24.655
# 36  pb_mutation_dynamic_geometric-default-at-target   7.368421052631579     2.074  -1.462    5.610  1.716  24.655
# 37                                    random_search   7.947368421052632     2.129  -1.407    5.665  1.716  24.655
# 38                                        hyperband   7.947368421052632     2.027  -1.509    5.563  1.716  24.655
# 39  pb_mutation_dynamic_geometric-default-at-target   7.947368421052632     2.070  -1.466    5.606  1.716  24.655
# 40                                    random_search   8.526315789473685     2.102  -1.434    5.638  1.716  24.655
# 41                                        hyperband   8.526315789473685     2.007  -1.529    5.543  1.716  24.655
# 42  pb_mutation_dynamic_geometric-default-at-target   8.526315789473685     2.003  -1.533    5.539  1.716  24.655
# 43                                    random_search   9.105263157894736     2.102  -1.434    5.638  1.716  24.655
# 44                                        hyperband   9.105263157894736     1.993  -1.543    5.529  1.716  24.655
# 45  pb_mutation_dynamic_geometric-default-at-target   9.105263157894736     1.983  -1.553    5.519  1.716  24.655
# 46                                    random_search    9.68421052631579     2.073  -1.463    5.609  1.716  24.655
# 47                                        hyperband    9.68421052631579     1.992  -1.544    5.528  1.716  24.655
# 48  pb_mutation_dynamic_geometric-default-at-target    9.68421052631579     1.980  -1.556    5.516  1.716  24.655
# 49                                    random_search  10.263157894736842     2.073  -1.463    5.609  1.716  24.655
# 50                                        hyperband  10.263157894736842     1.988  -1.548    5.524  1.716  24.655
# 51  pb_mutation_dynamic_geometric-default-at-target  10.263157894736842     1.971  -1.565    5.507  1.716  24.655
# 52                                    random_search  10.842105263157896     2.051  -1.485    5.587  1.716  24.655
# 53                                        hyperband  10.842105263157896     1.987  -1.549    5.523  1.716  24.655
# 54  pb_mutation_dynamic_geometric-default-at-target  10.842105263157896     1.970  -1.566    5.506  1.716  24.655
# 55                                    random_search  11.421052631578949     2.042  -1.494    5.578  1.716  24.655
# 56                                        hyperband  11.421052631578949     1.978  -1.558    5.514  1.716  24.655
# 57  pb_mutation_dynamic_geometric-default-at-target  11.421052631578949     1.964  -1.572    5.500  1.716  24.655,                                              Contrast  used_fidelity_bins  Estimate  2.5_ci  97.5_ci     SE         DF  T-stat  P-val  Sig
# 1                           random_search - hyperband                 1.0    -2.241  -2.768   -1.713  0.225  35968.999  -9.956  0.000  ***
# 2   random_search - (pb_mutation_dynamic_geometric...                 1.0   -12.421 -12.949  -11.894  0.225  35968.999 -55.185  0.000  ***
# 3   hyperband - (pb_mutation_dynamic_geometric-def...                 1.0   -10.181 -10.708   -9.653  0.225  35968.999 -45.230  0.000  ***
# 4                           random_search - hyperband  1.5789473684210527    -0.757  -1.503   -0.011  0.318  35968.999  -2.377  0.046    *
# 5   random_search - (pb_mutation_dynamic_geometric...  1.5789473684210527    -2.460  -3.206   -1.714  0.318  35968.999  -7.728  0.000  ***
# 6   hyperband - (pb_mutation_dynamic_geometric-def...  1.5789473684210527    -1.703  -2.449   -0.957  0.318  35968.999  -5.351  0.000  ***
# 7                           random_search - hyperband  2.1578947368421053    -0.712  -1.458    0.034  0.318  35968.999  -2.237  0.065    .
# 8   random_search - (pb_mutation_dynamic_geometric...  2.1578947368421053    -2.315  -3.061   -1.569  0.318  35968.999  -7.271  0.000  ***
# 9   hyperband - (pb_mutation_dynamic_geometric-def...  2.1578947368421053    -1.603  -2.349   -0.857  0.318  35968.999  -5.034  0.000  ***
# 10                          random_search - hyperband   2.736842105263158     0.264  -0.482    1.010  0.318  35968.999   0.829  0.685
# 11  random_search - (pb_mutation_dynamic_geometric...   2.736842105263158    -1.172  -1.918   -0.426  0.318  35968.999  -3.681  0.001  ***
# 12  hyperband - (pb_mutation_dynamic_geometric-def...   2.736842105263158    -1.436  -2.182   -0.690  0.318  35968.999  -4.511  0.000  ***
# 13                          random_search - hyperband  3.3157894736842106     0.268  -0.478    1.015  0.318  35968.999   0.843  0.676
# 14  random_search - (pb_mutation_dynamic_geometric...  3.3157894736842106    -1.156  -1.902   -0.409  0.318  35968.999  -3.630  0.001  ***
# 15  hyperband - (pb_mutation_dynamic_geometric-def...  3.3157894736842106    -1.424  -2.170   -0.678  0.318  35968.999  -4.474  0.000  ***
# 16                          random_search - hyperband  3.8947368421052633     0.119  -0.627    0.865  0.318  35968.999   0.373  0.926
# 17  random_search - (pb_mutation_dynamic_geometric...  3.8947368421052633     0.023  -0.723    0.770  0.318  35968.999   0.074  0.997
# 18  hyperband - (pb_mutation_dynamic_geometric-def...  3.8947368421052633    -0.095  -0.841    0.651  0.318  35968.999  -0.299  0.952
# 19                          random_search - hyperband   4.473684210526316     0.066  -0.680    0.812  0.318  35968.999   0.206  0.977
# 20  random_search - (pb_mutation_dynamic_geometric...   4.473684210526316    -0.026  -0.772    0.720  0.318  35968.999  -0.081  0.996
# 21  hyperband - (pb_mutation_dynamic_geometric-def...   4.473684210526316    -0.091  -0.837    0.655  0.318  35968.999  -0.287  0.956
# 22                          random_search - hyperband   5.052631578947368     0.159  -0.587    0.905  0.318  35968.999   0.501  0.871
# 23  random_search - (pb_mutation_dynamic_geometric...   5.052631578947368    -0.014  -0.760    0.732  0.318  35968.999  -0.045  0.999
# 24  hyperband - (pb_mutation_dynamic_geometric-def...   5.052631578947368    -0.174  -0.920    0.572  0.318  35968.999  -0.546  0.849
# 25                          random_search - hyperband   5.631578947368421     0.112  -0.634    0.858  0.318  35968.999   0.351  0.935
# 26  random_search - (pb_mutation_dynamic_geometric...   5.631578947368421    -0.058  -0.804    0.688  0.318  35968.999  -0.181  0.982
# 27  hyperband - (pb_mutation_dynamic_geometric-def...   5.631578947368421    -0.169  -0.915    0.577  0.318  35968.999  -0.532  0.856
# 28                          random_search - hyperband   6.210526315789474     0.112  -0.634    0.858  0.318  35968.999   0.353  0.934
# 29  random_search - (pb_mutation_dynamic_geometric...   6.210526315789474     0.113  -0.633    0.859  0.318  35968.999   0.355  0.933
# 30  hyperband - (pb_mutation_dynamic_geometric-def...   6.210526315789474     0.001  -0.745    0.747  0.318  35968.999   0.002  1.000
# 31                          random_search - hyperband  6.7894736842105265     0.083  -0.663    0.829  0.318  35968.999   0.262  0.963
# 32  random_search - (pb_mutation_dynamic_geometric...  6.7894736842105265     0.085  -0.661    0.831  0.318  35968.999   0.267  0.962
# 33  hyperband - (pb_mutation_dynamic_geometric-def...  6.7894736842105265     0.002  -0.744    0.748  0.318  35968.999   0.005  1.000
# 34                          random_search - hyperband   7.368421052631579     0.133  -0.613    0.879  0.318  35968.999   0.419  0.908
# 35  random_search - (pb_mutation_dynamic_geometric...   7.368421052631579     0.086  -0.660    0.832  0.318  35968.999   0.272  0.960
# 36  hyperband - (pb_mutation_dynamic_geometric-def...   7.368421052631579    -0.047  -0.793    0.699  0.318  35968.999  -0.147  0.988
# 37                          random_search - hyperband   7.947368421052632     0.102  -0.644    0.848  0.318  35968.999   0.320  0.945
# 38  random_search - (pb_mutation_dynamic_geometric...   7.947368421052632     0.059  -0.687    0.805  0.318  35968.999   0.186  0.981
# 39  hyperband - (pb_mutation_dynamic_geometric-def...   7.947368421052632    -0.043  -0.789    0.703  0.318  35968.999  -0.134  0.990
# 40                          random_search - hyperband   8.526315789473685     0.095  -0.651    0.842  0.318  35968.999   0.300  0.952
# 41  random_search - (pb_mutation_dynamic_geometric...   8.526315789473685     0.100  -0.646    0.846  0.318  35968.999   0.313  0.947
# 42  hyperband - (pb_mutation_dynamic_geometric-def...   8.526315789473685     0.004  -0.742    0.750  0.318  35968.999   0.013  1.000
# 43                          random_search - hyperband   9.105263157894736     0.110  -0.636    0.856  0.318  35968.999   0.345  0.937
# 44  random_search - (pb_mutation_dynamic_geometric...   9.105263157894736     0.119  -0.627    0.865  0.318  35968.999   0.374  0.926
# 45  hyperband - (pb_mutation_dynamic_geometric-def...   9.105263157894736     0.009  -0.737    0.755  0.318  35968.999   0.029  1.000
# 46                          random_search - hyperband    9.68421052631579     0.081  -0.665    0.827  0.318  35968.999   0.255  0.965
# 47  random_search - (pb_mutation_dynamic_geometric...    9.68421052631579     0.093  -0.653    0.839  0.318  35968.999   0.293  0.954
# 48  hyperband - (pb_mutation_dynamic_geometric-def...    9.68421052631579     0.012  -0.734    0.758  0.318  35968.999   0.038  0.999
# 49                          random_search - hyperband  10.263157894736842     0.085  -0.661    0.831  0.318  35968.999   0.268  0.961
# 50  random_search - (pb_mutation_dynamic_geometric...  10.263157894736842     0.102  -0.644    0.848  0.318  35968.999   0.319  0.945
# 51  hyperband - (pb_mutation_dynamic_geometric-def...  10.263157894736842     0.016  -0.730    0.762  0.318  35968.999   0.051  0.999
# 52                          random_search - hyperband  10.842105263157896     0.063  -0.683    0.809  0.318  35968.999   0.199  0.978
# 53  random_search - (pb_mutation_dynamic_geometric...  10.842105263157896     0.080  -0.666    0.826  0.318  35968.999   0.253  0.965
# 54  hyperband - (pb_mutation_dynamic_geometric-def...  10.842105263157896     0.017  -0.729    0.763  0.318  35968.999   0.054  0.998
# 55                          random_search - hyperband  11.421052631578949     0.063  -0.683    0.809  0.318  35968.999   0.199  0.978
# 56  random_search - (pb_mutation_dynamic_geometric...  11.421052631578949     0.077  -0.669    0.823  0.318  35968.999   0.243  0.968
# 57  hyperband - (pb_mutation_dynamic_geometric-def...  11.421052631578949     0.014  -0.732    0.760  0.318  35968.999   0.044  0.999     )
