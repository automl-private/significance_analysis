# %%
"""import os
import pickle
import sys

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import tabulate
from autorank import autorank, create_report, plot_stats
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import MultipleLocator"""
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pymer4.models import Lmer
from scipy import stats
from scipy.stats import rankdata
from dataset_management import get_dataset
from models import model
import itertools

pd.set_option("chained_assignment", None)
pd.set_option("display.max_rows", 5000)
pd.set_option("display.max_columns", 5000)
pd.set_option("display.width", 10000)

# %%
# Goal: Comprehensive list of all applicable models for the dataset

dataset=get_dataset(dataset_name="fig7_24_at25_bad_intsteps")

# %%
print(dataset.columns)
# Out:
# Index(['benchmark', 'prior', 'algorithm', 'used_fidelity', 'value', 'seed', 'bench_prior', 'regret', 'norm_regret', 'rel_rank'], dtype='object')

# %%
building_blocks=[]
for c_n,column in enumerate(['benchmark', 'prior', 'algorithm', 'used_fidelity', 'seed', 'bench_prior']):
    building_blocks.append(f" + {column}")
    building_blocks.append(f" + (1|{column})")

# mod=model(formula=f"value~(1|benchmark)*prior*algorithm",data=dataset,dummy=True)
# print(mod.summary())
# print(mod.post_hoc(marginal_vars="algorithm"),"\n\n")

for i in range(2,12):
    combs=list(itertools.combinations(building_blocks,i))
    print(len(combs))
    print(combs)
# Out:
# 66
# [(' + benchmark', ' + (1|benchmark)'), (' + benchmark', ' + prior'), (' + benchmark', ' + (1|prior)'), (' + benchmark', ' + algorithm'), (' + benchmark', ' + (1|algorithm)'), (' + benchmark', ' + used_fidelity'), (' + benchmark', ' + (1|used_fidelity)'), (' + benchmark', ' + seed'), (' + benchmark', ' + (1|seed)'), (' + benchmark', ' + bench_prior'), (' + benchmark', ' + (1|bench_prior)'), (' + (1|benchmark)', ' + prior'), (' + (1|benchmark)', ' + (1|prior)'), (' + (1|benchmark)', ' + algorithm'), (' + (1|benchmark)', ' + (1|algorithm)'), (' + (1|benchmark)', ' + used_fidelity'), (' + (1|benchmark)', ' + (1|used_fidelity)'), (' + (1|benchmark)', ' + seed'), (' + (1|benchmark)', ' + (1|seed)'), (' + (1|benchmark)', ' + bench_prior'), (' + (1|benchmark)', ' + (1|bench_prior)'), (' + prior', ' + (1|prior)'), (' + prior', ' + algorithm'), (' + prior', ' + (1|algorithm)'), (' + prior', ' + used_fidelity'), (' + prior', ' + (1|used_fidelity)'), (' + prior', ' + seed'), (' + prior', ' + (1|seed)'), (' + prior', ' + bench_prior'), (' + prior', ' + (1|bench_prior)'), (' + (1|prior)', ' + algorithm'), (' + (1|prior)', ' + (1|algorithm)'), (' + (1|prior)', ' + used_fidelity'), (' + (1|prior)', ' + (1|used_fidelity)'), (' + (1|prior)', ' + seed'), (' + (1|prior)', ' + (1|seed)'), (' + (1|prior)', ' + bench_prior'), (' + (1|prior)', ' + (1|bench_prior)'), (' + algorithm', ' + (1|algorithm)'), (' + algorithm', ' + used_fidelity'), (' + algorithm', ' + (1|used_fidelity)'), (' + algorithm', ' + seed'), (' + algorithm', ' + (1|seed)'), (' + algorithm', ' + bench_prior'), (' + algorithm', ' + (1|bench_prior)'), (' + (1|algorithm)', ' + used_fidelity'), (' + (1|algorithm)', ' + (1|used_fidelity)'), (' + (1|algorithm)', ' + seed'), (' + (1|algorithm)', ' + (1|seed)'), (' + (1|algorithm)', ' + bench_prior'), (' + (1|algorithm)', ' + (1|bench_prior)'), (' + used_fidelity', ' + (1|used_fidelity)'), (' + used_fidelity', ' + seed'), (' + used_fidelity', ' + (1|seed)'), (' + used_fidelity', ' + bench_prior'), (' + used_fidelity', ' + (1|bench_prior)'), (' + (1|used_fidelity)', ' + seed'), (' + (1|used_fidelity)', ' + (1|seed)'), (' + (1|used_fidelity)', ' + bench_prior'), (' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + seed', ' + (1|seed)'), (' + seed', ' + bench_prior'), (' + seed', ' + (1|bench_prior)'), (' + (1|seed)', ' + bench_prior'), (' + (1|seed)', ' + (1|bench_prior)'), (' + bench_prior', ' + (1|bench_prior)')]
# 220
# [(' + benchmark', ' + (1|benchmark)', ' + prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)'), (' + benchmark', ' + (1|benchmark)', ' + algorithm'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|bench_prior)'), (' + benchmark', ' + prior', ' + (1|prior)'), (' + benchmark', ' + prior', ' + algorithm'), (' + benchmark', ' + prior', ' + (1|algorithm)'), (' + benchmark', ' + prior', ' + used_fidelity'), (' + benchmark', ' + prior', ' + (1|used_fidelity)'), (' + benchmark', ' + prior', ' + seed'), (' + benchmark', ' + prior', ' + (1|seed)'), (' + benchmark', ' + prior', ' + bench_prior'), (' + benchmark', ' + prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|prior)', ' + algorithm'), (' + benchmark', ' + (1|prior)', ' + (1|algorithm)'), (' + benchmark', ' + (1|prior)', ' + used_fidelity'), (' + benchmark', ' + (1|prior)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|prior)', ' + seed'), (' + benchmark', ' + (1|prior)', ' + (1|seed)'), (' + benchmark', ' + (1|prior)', ' + bench_prior'), (' + benchmark', ' + (1|prior)', ' + (1|bench_prior)'), (' + benchmark', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + algorithm', ' + (1|used_fidelity)'), (' + benchmark', ' + algorithm', ' + seed'), (' + benchmark', ' + algorithm', ' + (1|seed)'), (' + benchmark', ' + algorithm', ' + bench_prior'), (' + benchmark', ' + algorithm', ' + (1|bench_prior)'), (' + benchmark', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + used_fidelity', ' + seed'), (' + benchmark', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + seed', ' + (1|seed)'), (' + benchmark', ' + seed', ' + bench_prior'), (' + benchmark', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + bench_prior', ' + (1|bench_prior)'), (' + (1|benchmark)', ' + prior', ' + (1|prior)'), (' + (1|benchmark)', ' + prior', ' + algorithm'), (' + (1|benchmark)', ' + prior', ' + (1|algorithm)'), (' + (1|benchmark)', ' + prior', ' + used_fidelity'), (' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)'), (' + (1|benchmark)', ' + prior', ' + seed'), (' + (1|benchmark)', ' + prior', ' + (1|seed)'), (' + (1|benchmark)', ' + prior', ' + bench_prior'), (' + (1|benchmark)', ' + prior', ' + (1|bench_prior)'), (' + (1|benchmark)', ' + (1|prior)', ' + algorithm'), (' + (1|benchmark)', ' + (1|prior)', ' + (1|algorithm)'), (' + (1|benchmark)', ' + (1|prior)', ' + used_fidelity'), (' + (1|benchmark)', ' + (1|prior)', ' + (1|used_fidelity)'), (' + (1|benchmark)', ' + (1|prior)', ' + seed'), (' + (1|benchmark)', ' + (1|prior)', ' + (1|seed)'), (' + (1|benchmark)', ' + (1|prior)', ' + bench_prior'), (' + (1|benchmark)', ' + (1|prior)', ' + (1|bench_prior)'), (' + (1|benchmark)', ' + algorithm', ' + (1|algorithm)'), (' + (1|benchmark)', ' + algorithm', ' + used_fidelity'), (' + (1|benchmark)', ' + algorithm' ...
# 495
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + algorithm', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + prior', ' + (1|prior)', ' + algorithm'), (' + benchmark', ' + prior', ' + (1|prior)', ' + (1|algorithm)'), (' + benchmark', ' + prior', ' + (1|prior)', ' + used_fidelity'), (' + benchmark', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)'), (' + benchmark', ' + prior', ' + (1|prior)', ' + seed'), (' + benchmark', ' + prior', ' + (1|prior)', ' + (1|seed)'), (' + benchmark', ' + prior', ' + (1|prior)', ' + bench_prior'), (' + benchmark', ' + prior', ' + (1|prior)', ' + (1|bench_prior)'), (' + benchmark', ' + prior', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + prior', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + prior', ' + algorithm', ' + (1|used_fidelity)'), (' + be ...
# 792
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + (1|algorithm)', ' + seed'), (' + b ...
# 924
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + used_fidelity', ' + (1 ...
# 792
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|b ...
# 495
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_pri ...
# 220
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + al ...
# 66
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)' ...
# 12
# [(' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + prior', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + (1|benchmark)', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + benchmark', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)'), (' + (1|benchmark)', ' + prior', ' + (1|prior)', ' + algorithm', ' + (1|algorithm)', ' + used_fidelity', ' + (1|used_fidelity)', ' + seed', ' + (1|seed)', ' + bench_prior', ' + (1|bench_prior)')]
